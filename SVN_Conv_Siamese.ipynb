# %% [markdown]
# Paper reference: https://arxiv.org/pdf/1707.02131.pdf
#
# - Focus on *offline* signature-verification which is *writer-independent*.
# - Challenging as compared to other one-shot tasks because writing styles could greatly differ.

# %%
# !pip install unrar
# Out:
# Collecting unrar
#   Downloading unrar-0.4-py3-none-any.whl (25 kB)
# Installing collected packages: unrar
# Successfully installed unrar-0.4

# %%
# !wget http://www.cedar.buffalo.edu/NIJ/data/signatures.rar
# Out:
# --2021-09-22 05:16:09--  http://www.cedar.buffalo.edu/NIJ/data/signatures.rar
# Resolving www.cedar.buffalo.edu (www.cedar.buffalo.edu)... 128.205.33.100
# Connecting to www.cedar.buffalo.edu (www.cedar.buffalo.edu)|128.205.33.100|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cedar.buffalo.edu/NIJ/data/signatures.rar [following]
# --2021-09-22 05:16:10--  https://cedar.buffalo.edu/NIJ/data/signatures.rar
# Resolving cedar.buffalo.edu (cedar.buffalo.edu)... 128.205.33.100
# Connecting to cedar.buffalo.edu (cedar.buffalo.edu)|128.205.33.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 253587033 (242M) [text/plain]
# Saving to: ‘signatures.rar’
#
# signatures.rar      100%[===================>] 241.84M  74.8MB/s    in 3.6s
#
# 2021-09-22 05:16:14 (66.3 MB/s) - ‘signatures.rar’ saved [253587033/253587033]

# %%
# !unrar x signatures.rar signatures/
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from signatures.rar
#
# Creating    signatures                                                OK
# Creating    signatures/signatures                                     OK
# Creating    signatures/signatures/full_forg                           OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    signatures/signatures/full_org                            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
import copy
import cv2
import os
import glob
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
base_dir = "signatures/signatures"

# %%
len(os.listdir(f"{base_dir}/full_org")), len(os.listdir(f"{base_dir}/full_forg"))
# Out:
# (1321, 1321)

# %%
class_range = np.arange(1, 56)
os.mkdir("processed_signatures/")

for i in class_range:
  os.mkdir("processed_signatures/" + str(i))

# %%
from tqdm.auto import tqdm
from joblib import Parallel, delayed

def _get_img_paths():
  for sigclass in os.listdir(base_dir):
    class_path = os.path.join(base_dir, sigclass)
    if class_path != "signatures/signatures/Readme.txt":
      for image in os.listdir(class_path):
        if image.endswith(".png"):
          yield os.path.join(class_path, image)

def preprocess_signature(img_path):
  signer = int(img_path.split("/")[-1].split("_")[-2])
  image = cv2.imread(img_path)
  if image is None:
    print(f"The image {img_path} cannot be read. Skipping")
    return
  # Bi-linear interpolation.
  image = cv2.resize(image, (155, 220), interpolation=cv2.INTER_LINEAR)
  # Invert image.
  image = cv2.bitwise_not(image)
  # Save image.
  filename = os.path.join("processed_signatures", f"{signer}", "proc_" + img_path.split("/")[-1])
  cv2.imwrite(filename, image)

# TODO: Use joblib for faster saving?
# _ = Parallel(n_jobs=-1)(delayed(preprocess_signature)(img_path) for img_path in tqdm(_get_img_paths(), total=1321*2))
for img_path in _get_img_paths():
  preprocess_signature(img_path)

# %%
# !ls processed_signatures/1 | wc -l
# Out:
# 48

# %%
# !ls processed_signatures/55 | wc -l
# Out:
# 48

# %%
# !zip -r processed_signatures.zip processed_signatures/
# Out:
#   adding: processed_signatures/ (stored 0%)
#   adding: processed_signatures/47/ (stored 0%)
#   adding: processed_signatures/47/proc_forgeries_47_21.png (deflated 22%)
#   adding: processed_signatures/47/proc_forgeries_47_10.png (deflated 21%)
#   adding: processed_signatures/47/proc_forgeries_47_8.png (deflated 14%)
#   adding: processed_signatures/47/proc_original_47_8.png (deflated 19%)
#   adding: processed_signatures/47/proc_original_47_15.png (deflated 17%)
#   adding: processed_signatures/47/proc_forgeries_47_19.png (deflated 20%)
#   adding: processed_signatures/47/proc_original_47_16.png (deflated 17%)
#   adding: processed_signatures/47/proc_original_47_5.png (deflated 17%)
#   adding: processed_signatures/47/proc_original_47_21.png (deflated 17%)
#   adding: processed_signatures/47/proc_forgeries_47_17.png (deflated 17%)
#   adding: processed_signatures/47/proc_original_47_3.png (deflated 17%)
#   adding: processed_signatures/47/proc_original_47_17.png (deflated 17%)
#   adding: processed_signatures/47/proc_original_47_20.png (deflated 18%)
#   adding: processed_signatures/47/proc_original_47_23.png (deflated 18%)
#   adding: processed_signatures/47/proc_forgeries_47_18.png (deflated 21%)
#   adding: processed_signatures/47/proc_forgeries_47_5.png (deflated 13%)
#   adding: processed_signatures/47/proc_original_47_12.png (deflated 19%)
#   adding: processed_signatures/47/proc_forgeries_47_15.png (deflated 21%)
#   adding: processed_signatures/47/proc_forgeries_47_11.png (deflated 16%)
#   adding: processed_signatures/47/proc_original_47_13.png (deflated 18%)
#   adding: processed_signatures/47/proc_forgeries_47_22.png (deflated 20%)
#   adding: processed_signatures/47/proc_forgeries_47_9.png (deflated 20%)
#   adding: processed_signatures/47/proc_forgeries_47_1.png (deflated 18%)
#   adding: processed_signatures/47/proc_forgeries_47_24.png (deflated 21%)
#   adding: processed_signatures/47/proc_original_47_10.png (deflated 18%)
#   adding: processed_signatures/47/proc_original_47_9.png (deflated 18%)
#   adding: processed_signatures/47/proc_forgeries_47_2.png (deflated 14%)
#   adding: processed_signatures/47/proc_original_47_19.png (deflated 17%)
#   adding: processed_signatures/47/proc_forgeries_47_13.png (deflated 20%)
#   adding: processed_signatures/47/proc_forgeries_47_20.png (deflated 17%)
#   adding: processed_signatures/47/proc_forgeries_47_4.png (deflated 17%)
#   adding: processed_signatures/47/proc_original_47_4.png (deflated 17%)
#   adding: processed_signatures/47/proc_forgeries_47_3.png (deflated 19%)
#   adding: processed_signatures/47/proc_original_47_11.png (deflated 18%)
#   adding: processed_signatures/47/proc_original_47_2.png (deflated 18%)
#   adding: processed_signatures/47/proc_forgeries_47_6.png (deflated 18%)
#   adding: processed_signatures/47/proc_forgeries_47_23.png (deflated 20%)
#   adding: processed_signatures/47/proc_forgeries_47_12.png (deflated 20%)
#   adding: processed_signatures/47/proc_original_47_22.png (deflated 18%)
#   adding: processed_signatures/47/proc_forgeries_47_7.png (deflated 19%)
#   adding: processed_signatures/47/proc_forgeries_47_16.png (deflated 20%)
#   adding: processed_signatures/47/proc_original_47_7.png (deflated 18%)
#   adding: processed_signatures/47/proc_original_47_24.png (deflated 17%)
#   adding: processed_signatures/47/proc_original_47_6.png (deflated 18%)
#   adding: processed_signatures/47/proc_original_47_1.png (deflated 17%)
#   adding: processed_signatures/47/proc_original_47_14.png (deflated 17%)
#   adding: processed_signatures/47/proc_original_47_18.png (deflated 18%)
#   adding: processed_signatures/47/proc_forgeries_47_14.png (deflated 18%)
#   adding: processed_signatures/20/ (stored 0%)
#   adding: processed_signatures/20/proc_forgeries_20_13.png (deflated 21%)
#   adding: processed_signatures/20/proc_forgeries_20_2.png (deflated 20%)
#   adding: processed_signatures/20/proc_original_20_16.png (deflated 20%)
#   adding: processed_signatures/20/proc_original_20_2.png (deflated 18%)
#   adding: processed_signatures/20/proc_forgeries_20_3.png (deflated 21%)
#   adding: processed_signatures/20/proc_forgeries_20_20.png (deflated 18%)
#   adding: processed_signatures/20/proc_original_20_23.png (deflated 18%)
#   adding: processed_signatures/20/proc_forgeries_20_14.png (deflated 19%)
#   adding: processed_signatures/20/proc_forgeries_20_18.png (deflated 22%)
#   adding: processed_signatures/20/proc_original_20_15.png (deflated 18%)
#   adding: processed_signatures/20/proc_original_20_10.png (deflated 20%)
#   adding: processed_signatures/20/proc_forgeries_20_9.png (deflated 22%)
#   adding: processed_signatures/20/proc_forgeries_20_11.png (deflated 21%)
#   adding: processed_signatures/20/proc_original_20_7.png (deflated 18%)
#   adding: processed_signatures/20/proc_original_20_11.png (deflated 20%)
#   adding: processed_signatures/20/proc_forgeries_20_7.png (deflated 22%)
#   adding: processed_signatures/20/proc_original_20_20.png (deflated 18%)
#   adding: processed_signatures/20/proc_original_20_21.png (deflated 20%)
#   adding: processed_signatures/20/proc_original_20_5.png (deflated 17%)
#   adding: processed_signatures/20/proc_original_20_6.png (deflated 17%)
#   adding: processed_signatures/20/proc_original_20_3.png (deflated 18%)
#   adding: processed_signatures/20/proc_original_20_4.png (deflated 18%)
#   adding: processed_signatures/20/proc_original_20_1.png (deflated 19%)
#   adding: processed_signatures/20/proc_forgeries_20_8.png (deflated 21%)
#   adding: processed_signatures/20/proc_original_20_12.png (deflated 18%)
#   adding: processed_signatures/20/proc_original_20_13.png (deflated 18%)
#   adding: processed_signatures/20/proc_forgeries_20_12.png (deflated 21%)
#   adding: processed_signatures/20/proc_original_20_22.png (deflated 18%)
#   adding: processed_signatures/20/proc_original_20_17.png (deflated 18%)
#   adding: processed_signatures/20/proc_forgeries_20_5.png (deflated 23%)
#   adding: processed_signatures/20/proc_forgeries_20_1.png (deflated 21%)
#   adding: processed_signatures/20/proc_forgeries_20_10.png (deflated 22%)
#   adding: processed_signatures/20/proc_forgeries_20_6.png (deflated 22%)
#   adding: processed_signatures/20/proc_forgeries_20_24.png (deflated 20%)
#   adding: processed_signatures/20/proc_forgeries_20_16.png (deflated 22%)
#   adding: processed_signatures/20/proc_forgeries_20_23.png (deflated 17%)
#   adding: processed_signatures/20/proc_forgeries_20_15.png (deflated 22%)
#   adding: processed_signatures/20/proc_forgeries_20_17.png (deflated 20%)
#   adding: processed_signatures/20/proc_original_20_14.png (deflated 19%)
#   adding: processed_signatures/20/proc_forgeries_20_21.png (deflated 19%)
#   adding: processed_signatures/20/proc_original_20_8.png (deflated 18%)
#   adding: processed_signatures/20/proc_forgeries_20_19.png (deflated 22%)
#   adding: processed_signatures/20/proc_original_20_24.png (deflated 19%)
#   adding: processed_signatures/20/proc_original_20_9.png (deflated 19%)
#   adding: processed_signatures/20/proc_original_20_19.png (deflated 19%)
#   adding: processed_signatures/20/proc_forgeries_20_4.png (deflated 22%)
#   adding: processed_signatures/20/proc_original_20_18.png (deflated 18%)
#   adding: processed_signatures/20/proc_forgeries_20_22.png (deflated 19%)
#   adding: processed_signatures/17/ (stored 0%)
#   adding: processed_signatures/17/proc_original_17_10.png (deflated 16%)
#   adding: processed_signatures/17/proc_original_17_16.png (deflated 16%)
#   adding: processed_signatures/17/proc_original_17_14.png (deflated 16%)
#   adding: processed_signatures/17/proc_original_17_6.png (deflated 16%)
#   adding: processed_signatures/17/proc_forgeries_17_1.png (deflated 16%)
#   adding: processed_signatures/17/proc_forgeries_17_12.png (deflated 16%)
#   adding: processed_signatures/17/proc_original_17_9.png (deflated 16%)
#   adding: processed_signatures/17/proc_original_17_21.png (deflated 17%)
#   adding: processed_signatures/17/proc_forgeries_17_3.png (deflated 17%)
#   adding: processed_signatures/17/proc_forgeries_17_13.png (deflated 16%)
#   adding: processed_signatures/17/proc_original_17_22.png (deflated 16%)
#   adding: processed_signatures/17/proc_original_17_4.png (deflated 16%)
#   adding: processed_signatures/17/proc_forgeries_17_18.png (deflated 16%)
#   adding: processed_signatures/17/proc_forgeries_17_4.png (deflated 16%)
#   adding: processed_signatures/17/proc_original_17_8.png (deflated 16%)
#   adding: processed_signatures/17/proc_forgeries_17_10.png (deflated 16%)
#   adding: processed_signatures/17/proc_forgeries_17_11.png (deflated 17%)
#   adding: processed_signatures/17/proc_forgeries_17_15.png (deflated 16%)
#   adding: processed_signatures/17/proc_original_17_24.png (deflated 16%)
#   adding: processed_signatures/17/proc_original_17_1.png (deflated 16%)
#   adding: processed_signatures/17/proc_original_17_3.png (deflated 16%)
#   adding: processed_signatures/17/proc_original_17_11.png (deflated 16%)
#   adding: processed_signatures/17/proc_forgeries_17_19.png (deflated 16%)
#   adding: processed_signatures/17/proc_original_17_23.png (deflated 17%)
#   adding: processed_signatures/17/proc_forgeries_17_14.png (deflated 16%)
#   adding: processed_signatures/17/proc_forgeries_17_6.png (deflated 16%)
#   adding: processed_signatures/17/proc_forgeries_17_2.png (deflated 17%)
#   adding: processed_signatures/17/proc_forgeries_17_9.png (deflated 16%)
#   adding: processed_signatures/17/proc_forgeries_17_16.png (deflated 16%)
#   adding: processed_signatures/17/proc_forgeries_17_24.png (deflated 17%)
#   adding: processed_signatures/17/proc_forgeries_17_23.png (deflated 16%)
#   adding: processed_signatures/17/proc_original_17_20.png (deflated 17%)
#   adding: processed_signatures/17/proc_original_17_2.png (deflated 16%)
#   adding: processed_signatures/17/proc_original_17_18.png (deflated 16%)
#   adding: processed_signatures/17/proc_original_17_5.png (deflated 15%)
#   adding: processed_signatures/17/proc_forgeries_17_17.png (deflated 16%)
#   adding: processed_signatures/17/proc_original_17_13.png (deflated 16%)
#   adding: processed_signatures/17/proc_forgeries_17_22.png (deflated 17%)
#   adding: processed_signatures/17/proc_original_17_17.png (deflated 16%)
#   adding: processed_signatures/17/proc_forgeries_17_20.png (deflated 16%)
#   adding: processed_signatures/17/proc_forgeries_17_7.png (deflated 16%)
#   adding: processed_signatures/17/proc_original_17_15.png (deflated 16%)
#   adding: processed_signatures/17/proc_forgeries_17_8.png (deflated 17%)
#   adding: processed_signatures/17/proc_original_17_7.png (deflated 16%)
#   adding: processed_signatures/17/proc_forgeries_17_5.png (deflated 17%)
#   adding: processed_signatures/17/proc_original_17_12.png (deflated 15%)
#   adding: processed_signatures/17/proc_forgeries_17_21.png (deflated 16%)
#   adding: processed_signatures/17/proc_original_17_19.png (deflated 16%)
#   adding: processed_signatures/33/ (stored 0%)
#   adding: processed_signatures/33/proc_forgeries_33_2.png (deflated 20%)
#   adding: processed_signatures/33/proc_forgeries_33_21.png (deflated 20%)
#   adding: processed_signatures/33/proc_original_33_12.png (deflated 18%)
#   adding: processed_signatures/33/proc_original_33_19.png (deflated 18%)
#   adding: processed_signatures/33/proc_forgeries_33_3.png (deflated 19%)
#   adding: processed_signatures/33/proc_forgeries_33_8.png (deflated 21%)
#   adding: processed_signatures/33/proc_forgeries_33_4.png (deflated 20%)
#   adding: processed_signatures/33/proc_original_33_1.png (deflated 18%)
#   adding: processed_signatures/33/proc_original_33_10.png (deflated 20%)
#   adding: processed_signatures/33/proc_forgeries_33_7.png (deflated 20%)
#   adding: processed_signatures/33/proc_original_33_6.png (deflated 18%)
#   adding: processed_signatures/33/proc_original_33_11.png (deflated 17%)
#   adding: processed_signatures/33/proc_original_33_15.png (deflated 19%)
#   adding: processed_signatures/33/proc_forgeries_33_19.png (deflated 19%)
#   adding: processed_signatures/33/proc_original_33_13.png (deflated 18%)
#   adding: processed_signatures/33/proc_forgeries_33_20.png (deflated 20%)
#   adding: processed_signatures/33/proc_original_33_8.png (deflated 18%)
#   adding: processed_signatures/33/proc_original_33_21.png (deflated 17%)
#   adding: processed_signatures/33/proc_original_33_20.png (deflated 19%)
#   adding: processed_signatures/33/proc_forgeries_33_14.png (deflated 20%)
#   adding: processed_signatures/33/proc_forgeries_33_15.png (deflated 19%)
#   adding: processed_signatures/33/proc_forgeries_33_18.png (deflated 20%)
#   adding: processed_signatures/33/proc_forgeries_33_6.png (deflated 20%)
#   adding: processed_signatures/33/proc_original_33_7.png (deflated 19%)
#   adding: processed_signatures/33/proc_original_33_16.png (deflated 18%)
#   adding: processed_signatures/33/proc_original_33_24.png (deflated 18%)
#   adding: processed_signatures/33/proc_original_33_17.png (deflated 18%)
#   adding: processed_signatures/33/proc_original_33_3.png (deflated 18%)
#   adding: processed_signatures/33/proc_forgeries_33_22.png (deflated 20%)
#   adding: processed_signatures/33/proc_forgeries_33_24.png (deflated 19%)
#   adding: processed_signatures/33/proc_forgeries_33_23.png (deflated 21%)
#   adding: processed_signatures/33/proc_forgeries_33_12.png (deflated 21%)
#   adding: processed_signatures/33/proc_forgeries_33_13.png (deflated 19%)
#   adding: processed_signatures/33/proc_original_33_23.png (deflated 18%)
#   adding: processed_signatures/33/proc_forgeries_33_1.png (deflated 20%)
#   adding: processed_signatures/33/proc_original_33_2.png (deflated 18%)
#   adding: processed_signatures/33/proc_original_33_18.png (deflated 17%)
#   adding: processed_signatures/33/proc_forgeries_33_17.png (deflated 19%)
#   adding: processed_signatures/33/proc_forgeries_33_9.png (deflated 18%)
#   adding: processed_signatures/33/proc_original_33_14.png (deflated 18%)
#   adding: processed_signatures/33/proc_original_33_22.png (deflated 18%)
#   adding: processed_signatures/33/proc_forgeries_33_5.png (deflated 20%)
#   adding: processed_signatures/33/proc_forgeries_33_10.png (deflated 19%)
#   adding: processed_signatures/33/proc_original_33_5.png (deflated 17%)
#   adding: processed_signatures/33/proc_forgeries_33_16.png (deflated 19%)
#   adding: processed_signatures/33/proc_original_33_4.png (deflated 18%)
#   adding: processed_signatures/33/proc_forgeries_33_11.png (deflated 19%)
#   adding: processed_signatures/33/proc_original_33_9.png (deflated 19%)
#   adding: processed_signatures/14/ (stored 0%)
#   adding: processed_signatures/14/proc_original_14_19.png (deflated 19%)
#   adding: processed_signatures/14/proc_original_14_13.png (deflated 18%)
#   adding: processed_signatures/14/proc_forgeries_14_19.png (deflated 20%)
#   adding: processed_signatures/14/proc_forgeries_14_20.png (deflated 21%)
#   adding: processed_signatures/14/proc_original_14_5.png (deflated 17%)
#   adding: processed_signatures/14/proc_forgeries_14_13.png (deflated 20%)
#   adding: processed_signatures/14/proc_original_14_7.png (deflated 19%)
#   adding: processed_signatures/14/proc_forgeries_14_10.png (deflated 20%)
#   adding: processed_signatures/14/proc_original_14_22.png (deflated 17%)
#   adding: processed_signatures/14/proc_original_14_24.png (deflated 18%)
#   adding: processed_signatures/14/proc_forgeries_14_18.png (deflated 20%)
#   adding: processed_signatures/14/proc_forgeries_14_14.png (deflated 21%)
#   adding: processed_signatures/14/proc_forgeries_14_16.png (deflated 21%)
#   adding: processed_signatures/14/proc_forgeries_14_9.png (deflated 20%)
#   adding: processed_signatures/14/proc_original_14_20.png (deflated 17%)
#   adding: processed_signatures/14/proc_original_14_17.png (deflated 17%)
#   adding: processed_signatures/14/proc_original_14_12.png (deflated 17%)
#   adding: processed_signatures/14/proc_original_14_4.png (deflated 18%)
#   adding: processed_signatures/14/proc_original_14_23.png (deflated 17%)
#   adding: processed_signatures/14/proc_forgeries_14_24.png (deflated 21%)
#   adding: processed_signatures/14/proc_forgeries_14_12.png (deflated 21%)
#   adding: processed_signatures/14/proc_forgeries_14_8.png (deflated 21%)
#   adding: processed_signatures/14/proc_forgeries_14_23.png (deflated 20%)
#   adding: processed_signatures/14/proc_forgeries_14_17.png (deflated 21%)
#   adding: processed_signatures/14/proc_forgeries_14_3.png (deflated 20%)
#   adding: processed_signatures/14/proc_original_14_3.png (deflated 17%)
#   adding: processed_signatures/14/proc_forgeries_14_1.png (deflated 21%)
#   adding: processed_signatures/14/proc_forgeries_14_11.png (deflated 20%)
#   adding: processed_signatures/14/proc_forgeries_14_22.png (deflated 20%)
#   adding: processed_signatures/14/proc_forgeries_14_6.png (deflated 21%)
#   adding: processed_signatures/14/proc_original_14_1.png (deflated 18%)
#   adding: processed_signatures/14/proc_original_14_9.png (deflated 18%)
#   adding: processed_signatures/14/proc_original_14_8.png (deflated 17%)
#   adding: processed_signatures/14/proc_original_14_15.png (deflated 17%)
#   adding: processed_signatures/14/proc_forgeries_14_4.png (deflated 20%)
#   adding: processed_signatures/14/proc_original_14_11.png (deflated 18%)
#   adding: processed_signatures/14/proc_original_14_2.png (deflated 18%)
#   adding: processed_signatures/14/proc_forgeries_14_21.png (deflated 20%)
#   adding: processed_signatures/14/proc_forgeries_14_5.png (deflated 21%)
#   adding: processed_signatures/14/proc_original_14_21.png (deflated 17%)
#   adding: processed_signatures/14/proc_forgeries_14_15.png (deflated 21%)
#   adding: processed_signatures/14/proc_original_14_6.png (deflated 18%)
#   adding: processed_signatures/14/proc_forgeries_14_2.png (deflated 22%)
#   adding: processed_signatures/14/proc_original_14_10.png (deflated 18%)
#   adding: processed_signatures/14/proc_original_14_18.png (deflated 17%)
#   adding: processed_signatures/14/proc_original_14_16.png (deflated 18%)
#   adding: processed_signatures/14/proc_forgeries_14_7.png (deflated 21%)
#   adding: processed_signatures/14/proc_original_14_14.png (deflated 18%)
#   adding: processed_signatures/26/ (stored 0%)
#   adding: processed_signatures/26/proc_forgeries_26_22.png (deflated 21%)
#   adding: processed_signatures/26/proc_original_26_5.png (deflated 20%)
#   adding: processed_signatures/26/proc_original_26_20.png (deflated 20%)
#   adding: processed_signatures/26/proc_original_26_22.png (deflated 19%)
#   adding: processed_signatures/26/proc_forgeries_26_23.png (deflated 21%)
#   adding: processed_signatures/26/proc_original_26_14.png (deflated 21%)
#   adding: processed_signatures/26/proc_forgeries_26_20.png (deflated 20%)
#   adding: processed_signatures/26/proc_forgeries_26_9.png (deflated 22%)
#   adding: processed_signatures/26/proc_original_26_23.png (deflated 19%)
#   adding: processed_signatures/26/proc_forgeries_26_15.png (deflated 18%)
#   adding: processed_signatures/26/proc_forgeries_26_5.png (deflated 22%)
#   adding: processed_signatures/26/proc_forgeries_26_18.png (deflated 19%)
#   adding: processed_signatures/26/proc_forgeries_26_1.png (deflated 23%)
#   adding: processed_signatures/26/proc_forgeries_26_16.png (deflated 21%)
#   adding: processed_signatures/26/proc_forgeries_26_21.png (deflated 20%)
#   adding: processed_signatures/26/proc_forgeries_26_14.png (deflated 19%)
#   adding: processed_signatures/26/proc_original_26_11.png (deflated 21%)
#   adding: processed_signatures/26/proc_forgeries_26_17.png (deflated 21%)
#   adding: processed_signatures/26/proc_forgeries_26_19.png (deflated 21%)
#   adding: processed_signatures/26/proc_original_26_24.png (deflated 20%)
#   adding: processed_signatures/26/proc_forgeries_26_4.png (deflated 22%)
#   adding: processed_signatures/26/proc_original_26_19.png (deflated 19%)
#   adding: processed_signatures/26/proc_original_26_13.png (deflated 20%)
#   adding: processed_signatures/26/proc_forgeries_26_6.png (deflated 22%)
#   adding: processed_signatures/26/proc_forgeries_26_2.png (deflated 21%)
#   adding: processed_signatures/26/proc_forgeries_26_24.png (deflated 18%)
#   adding: processed_signatures/26/proc_forgeries_26_10.png (deflated 20%)
#   adding: processed_signatures/26/proc_original_26_12.png (deflated 20%)
#   adding: processed_signatures/26/proc_original_26_16.png (deflated 19%)
#   adding: processed_signatures/26/proc_original_26_6.png (deflated 20%)
#   adding: processed_signatures/26/proc_forgeries_26_3.png (deflated 22%)
#   adding: processed_signatures/26/proc_original_26_4.png (deflated 19%)
#   adding: processed_signatures/26/proc_original_26_2.png (deflated 20%)
#   adding: processed_signatures/26/proc_original_26_7.png (deflated 20%)
#   adding: processed_signatures/26/proc_forgeries_26_13.png (deflated 19%)
#   adding: processed_signatures/26/proc_original_26_3.png (deflated 21%)
#   adding: processed_signatures/26/proc_original_26_18.png (deflated 20%)
#   adding: processed_signatures/26/proc_original_26_15.png (deflated 20%)
#   adding: processed_signatures/26/proc_forgeries_26_7.png (deflated 22%)
#   adding: processed_signatures/26/proc_forgeries_26_11.png (deflated 21%)
#   adding: processed_signatures/26/proc_forgeries_26_8.png (deflated 21%)
#   adding: processed_signatures/26/proc_original_26_8.png (deflated 21%)
#   adding: processed_signatures/26/proc_original_26_10.png (deflated 21%)
#   adding: processed_signatures/26/proc_forgeries_26_12.png (deflated 21%)
#   adding: processed_signatures/26/proc_original_26_17.png (deflated 20%)
#   adding: processed_signatures/26/proc_original_26_9.png (deflated 20%)
#   adding: processed_signatures/26/proc_original_26_1.png (deflated 19%)
#   adding: processed_signatures/26/proc_original_26_21.png (deflated 19%)
#   adding: processed_signatures/8/ (stored 0%)
#   adding: processed_signatures/8/proc_original_8_16.png (deflated 20%)
#   adding: processed_signatures/8/proc_original_8_19.png (deflated 18%)
#   adding: processed_signatures/8/proc_original_8_4.png (deflated 18%)
#   adding: processed_signatures/8/proc_forgeries_8_9.png (deflated 18%)
#   adding: processed_signatures/8/proc_forgeries_8_11.png (deflated 19%)
#   adding: processed_signatures/8/proc_forgeries_8_7.png (deflated 19%)
#   adding: processed_signatures/8/proc_original_8_11.png (deflated 18%)
#   adding: processed_signatures/8/proc_forgeries_8_12.png (deflated 19%)
#   adding: processed_signatures/8/proc_forgeries_8_2.png (deflated 19%)
#   adding: processed_signatures/8/proc_original_8_20.png (deflated 18%)
#   adding: processed_signatures/8/proc_original_8_24.png (deflated 18%)
#   adding: processed_signatures/8/proc_forgeries_8_6.png (deflated 18%)
#   adding: processed_signatures/8/proc_forgeries_8_18.png (deflated 19%)
#   adding: processed_signatures/8/proc_original_8_13.png (deflated 18%)
#   adding: processed_signatures/8/proc_forgeries_8_16.png (deflated 17%)
#   adding: processed_signatures/8/proc_forgeries_8_14.png (deflated 19%)
#   adding: processed_signatures/8/proc_forgeries_8_3.png (deflated 19%)
#   adding: processed_signatures/8/proc_forgeries_8_15.png (deflated 18%)
#   adding: processed_signatures/8/proc_forgeries_8_24.png (deflated 17%)
#   adding: processed_signatures/8/proc_forgeries_8_22.png (deflated 18%)
#   adding: processed_signatures/8/proc_forgeries_8_17.png (deflated 18%)
#   adding: processed_signatures/8/proc_forgeries_8_5.png (deflated 19%)
#   adding: processed_signatures/8/proc_forgeries_8_20.png (deflated 18%)
#   adding: processed_signatures/8/proc_original_8_12.png (deflated 18%)
#   adding: processed_signatures/8/proc_original_8_21.png (deflated 19%)
#   adding: processed_signatures/8/proc_original_8_1.png (deflated 18%)
#   adding: processed_signatures/8/proc_original_8_15.png (deflated 18%)
#   adding: processed_signatures/8/proc_forgeries_8_23.png (deflated 18%)
#   adding: processed_signatures/8/proc_original_8_9.png (deflated 18%)
#   adding: processed_signatures/8/proc_original_8_6.png (deflated 19%)
#   adding: processed_signatures/8/proc_original_8_22.png (deflated 18%)
#   adding: processed_signatures/8/proc_original_8_3.png (deflated 18%)
#   adding: processed_signatures/8/proc_forgeries_8_21.png (deflated 17%)
#   adding: processed_signatures/8/proc_original_8_2.png (deflated 17%)
#   adding: processed_signatures/8/proc_original_8_5.png (deflated 18%)
#   adding: processed_signatures/8/proc_original_8_7.png (deflated 18%)
#   adding: processed_signatures/8/proc_original_8_10.png (deflated 18%)
#   adding: processed_signatures/8/proc_original_8_17.png (deflated 18%)
#   adding: processed_signatures/8/proc_forgeries_8_8.png (deflated 19%)
#   adding: processed_signatures/8/proc_forgeries_8_10.png (deflated 18%)
#   adding: processed_signatures/8/proc_original_8_23.png (deflated 18%)
#   adding: processed_signatures/8/proc_forgeries_8_13.png (deflated 18%)
#   adding: processed_signatures/8/proc_original_8_8.png (deflated 17%)
#   adding: processed_signatures/8/proc_forgeries_8_19.png (deflated 19%)
#   adding: processed_signatures/8/proc_original_8_18.png (deflated 17%)
#   adding: processed_signatures/8/proc_forgeries_8_4.png (deflated 19%)
#   adding: processed_signatures/8/proc_original_8_14.png (deflated 18%)
#   adding: processed_signatures/8/proc_forgeries_8_1.png (deflated 19%)
#   adding: processed_signatures/22/ (stored 0%)
#   adding: processed_signatures/22/proc_forgeries_22_6.png (deflated 20%)
#   adding: processed_signatures/22/proc_forgeries_22_7.png (deflated 20%)
#   adding: processed_signatures/22/proc_forgeries_22_19.png (deflated 20%)
#   adding: processed_signatures/22/proc_original_22_21.png (deflated 18%)
#   adding: processed_signatures/22/proc_forgeries_22_8.png (deflated 21%)
#   adding: processed_signatures/22/proc_original_22_19.png (deflated 19%)
#   adding: processed_signatures/22/proc_original_22_10.png (deflated 18%)
#   adding: processed_signatures/22/proc_forgeries_22_24.png (deflated 20%)
#   adding: processed_signatures/22/proc_forgeries_22_10.png (deflated 20%)
#   adding: processed_signatures/22/proc_original_22_13.png (deflated 19%)
#   adding: processed_signatures/22/proc_original_22_7.png (deflated 18%)
#   adding: processed_signatures/22/proc_forgeries_22_20.png (deflated 18%)
#   adding: processed_signatures/22/proc_forgeries_22_18.png (deflated 20%)
#   adding: processed_signatures/22/proc_original_22_3.png (deflated 18%)
#   adding: processed_signatures/22/proc_forgeries_22_22.png (deflated 18%)
#   adding: processed_signatures/22/proc_original_22_2.png (deflated 16%)
#   adding: processed_signatures/22/proc_forgeries_22_13.png (deflated 19%)
#   adding: processed_signatures/22/proc_original_22_6.png (deflated 16%)
#   adding: processed_signatures/22/proc_forgeries_22_5.png (deflated 21%)
#   adding: processed_signatures/22/proc_original_22_12.png (deflated 17%)
#   adding: processed_signatures/22/proc_forgeries_22_14.png (deflated 19%)
#   adding: processed_signatures/22/proc_original_22_17.png (deflated 18%)
#   adding: processed_signatures/22/proc_original_22_15.png (deflated 17%)
#   adding: processed_signatures/22/proc_original_22_14.png (deflated 17%)
#   adding: processed_signatures/22/proc_original_22_16.png (deflated 19%)
#   adding: processed_signatures/22/proc_forgeries_22_9.png (deflated 20%)
#   adding: processed_signatures/22/proc_original_22_23.png (deflated 18%)
#   adding: processed_signatures/22/proc_forgeries_22_2.png (deflated 20%)
#   adding: processed_signatures/22/proc_forgeries_22_12.png (deflated 20%)
#   adding: processed_signatures/22/proc_original_22_9.png (deflated 18%)
#   adding: processed_signatures/22/proc_forgeries_22_21.png (deflated 19%)
#   adding: processed_signatures/22/proc_forgeries_22_23.png (deflated 19%)
#   adding: processed_signatures/22/proc_original_22_18.png (deflated 18%)
#   adding: processed_signatures/22/proc_original_22_4.png (deflated 17%)
#   adding: processed_signatures/22/proc_forgeries_22_1.png (deflated 20%)
#   adding: processed_signatures/22/proc_forgeries_22_3.png (deflated 20%)
#   adding: processed_signatures/22/proc_forgeries_22_17.png (deflated 20%)
#   adding: processed_signatures/22/proc_forgeries_22_15.png (deflated 19%)
#   adding: processed_signatures/22/proc_forgeries_22_16.png (deflated 20%)
#   adding: processed_signatures/22/proc_forgeries_22_11.png (deflated 19%)
#   adding: processed_signatures/22/proc_original_22_11.png (deflated 18%)
#   adding: processed_signatures/22/proc_original_22_8.png (deflated 17%)
#   adding: processed_signatures/22/proc_original_22_1.png (deflated 17%)
#   adding: processed_signatures/22/proc_forgeries_22_4.png (deflated 19%)
#   adding: processed_signatures/22/proc_original_22_5.png (deflated 17%)
#   adding: processed_signatures/22/proc_original_22_20.png (deflated 17%)
#   adding: processed_signatures/22/proc_original_22_22.png (deflated 18%)
#   adding: processed_signatures/22/proc_original_22_24.png (deflated 17%)
#   adding: processed_signatures/51/ (stored 0%)
#   adding: processed_signatures/51/proc_original_51_13.png (deflated 17%)
#   adding: processed_signatures/51/proc_forgeries_51_8.png (deflated 19%)
#   adding: processed_signatures/51/proc_forgeries_51_24.png (deflated 18%)
#   adding: processed_signatures/51/proc_original_51_20.png (deflated 18%)
#   adding: processed_signatures/51/proc_forgeries_51_10.png (deflated 17%)
#   adding: processed_signatures/51/proc_original_51_1.png (deflated 17%)
#   adding: processed_signatures/51/proc_forgeries_51_3.png (deflated 18%)
#   adding: processed_signatures/51/proc_forgeries_51_22.png (deflated 18%)
#   adding: processed_signatures/51/proc_original_51_10.png (deflated 18%)
#   adding: processed_signatures/51/proc_forgeries_51_12.png (deflated 18%)
#   adding: processed_signatures/51/proc_forgeries_51_16.png (deflated 18%)
#   adding: processed_signatures/51/proc_original_51_4.png (deflated 16%)
#   adding: processed_signatures/51/proc_forgeries_51_23.png (deflated 17%)
#   adding: processed_signatures/51/proc_forgeries_51_2.png (deflated 20%)
#   adding: processed_signatures/51/proc_original_51_7.png (deflated 18%)
#   adding: processed_signatures/51/proc_forgeries_51_1.png (deflated 19%)
#   adding: processed_signatures/51/proc_forgeries_51_6.png (deflated 17%)
#   adding: processed_signatures/51/proc_original_51_9.png (deflated 17%)
#   adding: processed_signatures/51/proc_original_51_2.png (deflated 17%)
#   adding: processed_signatures/51/proc_original_51_3.png (deflated 17%)
#   adding: processed_signatures/51/proc_original_51_18.png (deflated 17%)
#   adding: processed_signatures/51/proc_forgeries_51_18.png (deflated 17%)
#   adding: processed_signatures/51/proc_original_51_12.png (deflated 16%)
#   adding: processed_signatures/51/proc_original_51_24.png (deflated 17%)
#   adding: processed_signatures/51/proc_forgeries_51_13.png (deflated 17%)
#   adding: processed_signatures/51/proc_original_51_19.png (deflated 17%)
#   adding: processed_signatures/51/proc_original_51_17.png (deflated 18%)
#   adding: processed_signatures/51/proc_forgeries_51_14.png (deflated 20%)
#   adding: processed_signatures/51/proc_original_51_5.png (deflated 17%)
#   adding: processed_signatures/51/proc_original_51_11.png (deflated 16%)
#   adding: processed_signatures/51/proc_forgeries_51_11.png (deflated 18%)
#   adding: processed_signatures/51/proc_forgeries_51_15.png (deflated 17%)
#   adding: processed_signatures/51/proc_original_51_22.png (deflated 17%)
#   adding: processed_signatures/51/proc_forgeries_51_19.png (deflated 18%)
#   adding: processed_signatures/51/proc_original_51_15.png (deflated 17%)
#   adding: processed_signatures/51/proc_forgeries_51_17.png (deflated 19%)
#   adding: processed_signatures/51/proc_forgeries_51_20.png (deflated 19%)
#   adding: processed_signatures/51/proc_original_51_21.png (deflated 16%)
#   adding: processed_signatures/51/proc_forgeries_51_7.png (deflated 17%)
#   adding: processed_signatures/51/proc_forgeries_51_9.png (deflated 17%)
#   adding: processed_signatures/51/proc_original_51_16.png (deflated 17%)
#   adding: processed_signatures/51/proc_forgeries_51_21.png (deflated 18%)
#   adding: processed_signatures/51/proc_original_51_8.png (deflated 17%)
#   adding: processed_signatures/51/proc_original_51_23.png (deflated 17%)
#   adding: processed_signatures/51/proc_forgeries_51_5.png (deflated 18%)
#   adding: processed_signatures/51/proc_original_51_14.png (deflated 18%)
#   adding: processed_signatures/51/proc_forgeries_51_4.png (deflated 18%)
#   adding: processed_signatures/51/proc_original_51_6.png (deflated 17%)
#   adding: processed_signatures/19/ (stored 0%)
#   adding: processed_signatures/19/proc_original_19_15.png (deflated 18%)
#   adding: processed_signatures/19/proc_original_19_5.png (deflated 17%)
#   adding: processed_signatures/19/proc_forgeries_19_1.png (deflated 18%)
#   adding: processed_signatures/19/proc_forgeries_19_6.png (deflated 17%)
#   adding: processed_signatures/19/proc_original_19_12.png (deflated 17%)
#   adding: processed_signatures/19/proc_forgeries_19_13.png (deflated 23%)
#   adding: processed_signatures/19/proc_forgeries_19_24.png (deflated 22%)
#   adding: processed_signatures/19/proc_original_19_2.png (deflated 17%)
#   adding: processed_signatures/19/proc_forgeries_19_15.png (deflated 22%)
#   adding: processed_signatures/19/proc_forgeries_19_4.png (deflated 16%)
#   adding: processed_signatures/19/proc_original_19_3.png (deflated 17%)
#   adding: processed_signatures/19/proc_original_19_7.png (deflated 18%)
#   adding: processed_signatures/19/proc_original_19_16.png (deflated 18%)
#   adding: processed_signatures/19/proc_forgeries_19_12.png (deflated 17%)
#   adding: processed_signatures/19/proc_original_19_20.png (deflated 18%)
#   adding: processed_signatures/19/proc_original_19_23.png (deflated 17%)
#   adding: processed_signatures/19/proc_forgeries_19_7.png (deflated 17%)
#   adding: processed_signatures/19/proc_forgeries_19_17.png (deflated 19%)
#   adding: processed_signatures/19/proc_forgeries_19_20.png (deflated 16%)
#   adding: processed_signatures/19/proc_original_19_4.png (deflated 18%)
#   adding: processed_signatures/19/proc_forgeries_19_19.png (deflated 22%)
#   adding: processed_signatures/19/proc_original_19_17.png (deflated 17%)
#   adding: processed_signatures/19/proc_original_19_1.png (deflated 18%)
#   adding: processed_signatures/19/proc_original_19_22.png (deflated 19%)
#   adding: processed_signatures/19/proc_forgeries_19_5.png (deflated 16%)
#   adding: processed_signatures/19/proc_forgeries_19_3.png (deflated 17%)
#   adding: processed_signatures/19/proc_original_19_11.png (deflated 17%)
#   adding: processed_signatures/19/proc_original_19_13.png (deflated 18%)
#   adding: processed_signatures/19/proc_forgeries_19_16.png (deflated 23%)
#   adding: processed_signatures/19/proc_original_19_19.png (deflated 18%)
#   adding: processed_signatures/19/proc_forgeries_19_2.png (deflated 15%)
#   adding: processed_signatures/19/proc_original_19_9.png (deflated 18%)
#   adding: processed_signatures/19/proc_forgeries_19_22.png (deflated 21%)
#   adding: processed_signatures/19/proc_forgeries_19_23.png (deflated 18%)
#   adding: processed_signatures/19/proc_original_19_6.png (deflated 18%)
#   adding: processed_signatures/19/proc_original_19_10.png (deflated 19%)
#   adding: processed_signatures/19/proc_forgeries_19_10.png (deflated 18%)
#   adding: processed_signatures/19/proc_forgeries_19_8.png (deflated 15%)
#   adding: processed_signatures/19/proc_forgeries_19_9.png (deflated 17%)
#   adding: processed_signatures/19/proc_original_19_24.png (deflated 19%)
#   adding: processed_signatures/19/proc_original_19_8.png (deflated 17%)
#   adding: processed_signatures/19/proc_original_19_21.png (deflated 17%)
#   adding: processed_signatures/19/proc_forgeries_19_11.png (deflated 15%)
#   adding: processed_signatures/19/proc_forgeries_19_18.png (deflated 22%)
#   adding: processed_signatures/19/proc_forgeries_19_14.png (deflated 20%)
#   adding: processed_signatures/19/proc_forgeries_19_21.png (deflated 20%)
#   adding: processed_signatures/19/proc_original_19_14.png (deflated 18%)
#   adding: processed_signatures/19/proc_original_19_18.png (deflated 17%)
#   adding: processed_signatures/42/ (stored 0%)
#   adding: processed_signatures/42/proc_forgeries_42_3.png (deflated 20%)
#   adding: processed_signatures/42/proc_original_42_23.png (deflated 17%)
#   adding: processed_signatures/42/proc_forgeries_42_14.png (deflated 20%)
#   adding: processed_signatures/42/proc_original_42_18.png (deflated 18%)
#   adding: processed_signatures/42/proc_original_42_10.png (deflated 19%)
#   adding: processed_signatures/42/proc_original_42_9.png (deflated 18%)
#   adding: processed_signatures/42/proc_original_42_14.png (deflated 18%)
#   adding: processed_signatures/42/proc_original_42_13.png (deflated 18%)
#   adding: processed_signatures/42/proc_forgeries_42_13.png (deflated 20%)
#   adding: processed_signatures/42/proc_forgeries_42_9.png (deflated 18%)
#   adding: processed_signatures/42/proc_forgeries_42_1.png (deflated 21%)
#   adding: processed_signatures/42/proc_forgeries_42_12.png (deflated 20%)
#   adding: processed_signatures/42/proc_forgeries_42_6.png (deflated 20%)
#   adding: processed_signatures/42/proc_original_42_21.png (deflated 18%)
#   adding: processed_signatures/42/proc_original_42_17.png (deflated 18%)
#   adding: processed_signatures/42/proc_forgeries_42_16.png (deflated 20%)
#   adding: processed_signatures/42/proc_original_42_7.png (deflated 18%)
#   adding: processed_signatures/42/proc_forgeries_42_2.png (deflated 21%)
#   adding: processed_signatures/42/proc_forgeries_42_5.png (deflated 21%)
#   adding: processed_signatures/42/proc_forgeries_42_10.png (deflated 20%)
#   adding: processed_signatures/42/proc_original_42_24.png (deflated 18%)
#   adding: processed_signatures/42/proc_forgeries_42_8.png (deflated 21%)
#   adding: processed_signatures/42/proc_original_42_1.png (deflated 17%)
#   adding: processed_signatures/42/proc_original_42_22.png (deflated 18%)
#   adding: processed_signatures/42/proc_original_42_8.png (deflated 19%)
#   adding: processed_signatures/42/proc_original_42_12.png (deflated 19%)
#   adding: processed_signatures/42/proc_forgeries_42_19.png (deflated 19%)
#   adding: processed_signatures/42/proc_forgeries_42_4.png (deflated 20%)
#   adding: processed_signatures/42/proc_original_42_4.png (deflated 19%)
#   adding: processed_signatures/42/proc_original_42_15.png (deflated 19%)
#   adding: processed_signatures/42/proc_forgeries_42_17.png (deflated 20%)
#   adding: processed_signatures/42/proc_forgeries_42_22.png (deflated 20%)
#   adding: processed_signatures/42/proc_original_42_3.png (deflated 19%)
#   adding: processed_signatures/42/proc_original_42_6.png (deflated 19%)
#   adding: processed_signatures/42/proc_forgeries_42_20.png (deflated 21%)
#   adding: processed_signatures/42/proc_forgeries_42_7.png (deflated 20%)
#   adding: processed_signatures/42/proc_original_42_11.png (deflated 17%)
#   adding: processed_signatures/42/proc_forgeries_42_11.png (deflated 21%)
#   adding: processed_signatures/42/proc_original_42_5.png (deflated 17%)
#   adding: processed_signatures/42/proc_forgeries_42_23.png (deflated 19%)
#   adding: processed_signatures/42/proc_original_42_20.png (deflated 17%)
#   adding: processed_signatures/42/proc_forgeries_42_24.png (deflated 20%)
#   adding: processed_signatures/42/proc_original_42_16.png (deflated 18%)
#   adding: processed_signatures/42/proc_original_42_19.png (deflated 17%)
#   adding: processed_signatures/42/proc_original_42_2.png (deflated 18%)
#   adding: processed_signatures/42/proc_forgeries_42_21.png (deflated 19%)
#   adding: processed_signatures/42/proc_forgeries_42_18.png (deflated 20%)
#   adding: processed_signatures/42/proc_forgeries_42_15.png (deflated 21%)
#   adding: processed_signatures/31/ (stored 0%)
#   adding: processed_signatures/31/proc_original_31_16.png (deflated 17%)
#   adding: processed_signatures/31/proc_forgeries_31_12.png (deflated 20%)
#   adding: processed_signatures/31/proc_forgeries_31_5.png (deflated 18%)
#   adding: processed_signatures/31/proc_forgeries_31_18.png (deflated 19%)
#   adding: processed_signatures/31/proc_original_31_18.png (deflated 17%)
#   adding: processed_signatures/31/proc_forgeries_31_19.png (deflated 19%)
#   adding: processed_signatures/31/proc_forgeries_31_2.png (deflated 20%)
#   adding: processed_signatures/31/proc_forgeries_31_21.png (deflated 19%)
#   adding: processed_signatures/31/proc_original_31_7.png (deflated 18%)
#   adding: processed_signatures/31/proc_original_31_22.png (deflated 17%)
#   adding: processed_signatures/31/proc_original_31_23.png (deflated 18%)
#   adding: processed_signatures/31/proc_forgeries_31_3.png (deflated 19%)
#   adding: processed_signatures/31/proc_forgeries_31_10.png (deflated 19%)
#   adding: processed_signatures/31/proc_original_31_1.png (deflated 16%)
#   adding: processed_signatures/31/proc_forgeries_31_16.png (deflated 19%)
#   adding: processed_signatures/31/proc_original_31_10.png (deflated 17%)
#   adding: processed_signatures/31/proc_original_31_9.png (deflated 17%)
#   adding: processed_signatures/31/proc_original_31_2.png (deflated 17%)
#   adding: processed_signatures/31/proc_original_31_21.png (deflated 17%)
#   adding: processed_signatures/31/proc_original_31_24.png (deflated 17%)
#   adding: processed_signatures/31/proc_forgeries_31_11.png (deflated 19%)
#   adding: processed_signatures/31/proc_forgeries_31_23.png (deflated 20%)
#   adding: processed_signatures/31/proc_forgeries_31_22.png (deflated 19%)
#   adding: processed_signatures/31/proc_forgeries_31_1.png (deflated 19%)
#   adding: processed_signatures/31/proc_forgeries_31_6.png (deflated 18%)
#   adding: processed_signatures/31/proc_forgeries_31_13.png (deflated 19%)
#   adding: processed_signatures/31/proc_original_31_12.png (deflated 16%)
#   adding: processed_signatures/31/proc_forgeries_31_9.png (deflated 19%)
#   adding: processed_signatures/31/proc_forgeries_31_8.png (deflated 18%)
#   adding: processed_signatures/31/proc_forgeries_31_15.png (deflated 20%)
#   adding: processed_signatures/31/proc_forgeries_31_14.png (deflated 20%)
#   adding: processed_signatures/31/proc_original_31_8.png (deflated 17%)
#   adding: processed_signatures/31/proc_original_31_15.png (deflated 18%)
#   adding: processed_signatures/31/proc_original_31_14.png (deflated 19%)
#   adding: processed_signatures/31/proc_forgeries_31_7.png (deflated 18%)
#   adding: processed_signatures/31/proc_original_31_20.png (deflated 16%)
#   adding: processed_signatures/31/proc_original_31_17.png (deflated 17%)
#   adding: processed_signatures/31/proc_forgeries_31_24.png (deflated 19%)
#   adding: processed_signatures/31/proc_forgeries_31_17.png (deflated 19%)
#   adding: processed_signatures/31/proc_original_31_19.png (deflated 17%)
#   adding: processed_signatures/31/proc_original_31_6.png (deflated 17%)
#   adding: processed_signatures/31/proc_original_31_3.png (deflated 18%)
#   adding: processed_signatures/31/proc_original_31_5.png (deflated 17%)
#   adding: processed_signatures/31/proc_original_31_13.png (deflated 17%)
#   adding: processed_signatures/31/proc_forgeries_31_4.png (deflated 17%)
#   adding: processed_signatures/31/proc_original_31_4.png (deflated 17%)
#   adding: processed_signatures/31/proc_forgeries_31_20.png (deflated 20%)
#   adding: processed_signatures/31/proc_original_31_11.png (deflated 17%)
#   adding: processed_signatures/41/ (stored 0%)
#   adding: processed_signatures/41/proc_original_41_22.png (deflated 17%)
#   adding: processed_signatures/41/proc_forgeries_41_22.png (deflated 20%)
#   adding: processed_signatures/41/proc_original_41_17.png (deflated 18%)
#   adding: processed_signatures/41/proc_original_41_16.png (deflated 18%)
#   adding: processed_signatures/41/proc_forgeries_41_2.png (deflated 23%)
#   adding: processed_signatures/41/proc_forgeries_41_5.png (deflated 21%)
#   adding: processed_signatures/41/proc_original_41_6.png (deflated 19%)
#   adding: processed_signatures/41/proc_original_41_1.png (deflated 17%)
#   adding: processed_signatures/41/proc_forgeries_41_12.png (deflated 19%)
#   adding: processed_signatures/41/proc_original_41_14.png (deflated 18%)
#   adding: processed_signatures/41/proc_original_41_10.png (deflated 18%)
#   adding: processed_signatures/41/proc_original_41_18.png (deflated 17%)
#   adding: processed_signatures/41/proc_forgeries_41_18.png (deflated 20%)
#   adding: processed_signatures/41/proc_original_41_11.png (deflated 17%)
#   adding: processed_signatures/41/proc_forgeries_41_10.png (deflated 22%)
#   adding: processed_signatures/41/proc_original_41_7.png (deflated 18%)
#   adding: processed_signatures/41/proc_forgeries_41_3.png (deflated 20%)
#   adding: processed_signatures/41/proc_original_41_9.png (deflated 18%)
#   adding: processed_signatures/41/proc_forgeries_41_1.png (deflated 20%)
#   adding: processed_signatures/41/proc_original_41_15.png (deflated 18%)
#   adding: processed_signatures/41/proc_forgeries_41_9.png (deflated 23%)
#   adding: processed_signatures/41/proc_forgeries_41_15.png (deflated 20%)
#   adding: processed_signatures/41/proc_original_41_2.png (deflated 18%)
#   adding: processed_signatures/41/proc_forgeries_41_24.png (deflated 19%)
#   adding: processed_signatures/41/proc_forgeries_41_17.png (deflated 22%)
#   adding: processed_signatures/41/proc_original_41_24.png (deflated 17%)
#   adding: processed_signatures/41/proc_forgeries_41_7.png (deflated 20%)
#   adding: processed_signatures/41/proc_forgeries_41_21.png (deflated 21%)
#   adding: processed_signatures/41/proc_original_41_20.png (deflated 17%)
#   adding: processed_signatures/41/proc_forgeries_41_4.png (deflated 21%)
#   adding: processed_signatures/41/proc_original_41_21.png (deflated 17%)
#   adding: processed_signatures/41/proc_forgeries_41_20.png (deflated 21%)
#   adding: processed_signatures/41/proc_original_41_19.png (deflated 17%)
#   adding: processed_signatures/41/proc_original_41_13.png (deflated 18%)
#   adding: processed_signatures/41/proc_original_41_3.png (deflated 18%)
#   adding: processed_signatures/41/proc_forgeries_41_13.png (deflated 21%)
#   adding: processed_signatures/41/proc_original_41_8.png (deflated 18%)
#   adding: processed_signatures/41/proc_original_41_12.png (deflated 17%)
#   adding: processed_signatures/41/proc_forgeries_41_19.png (deflated 21%)
#   adding: processed_signatures/41/proc_forgeries_41_23.png (deflated 22%)
#   adding: processed_signatures/41/proc_original_41_5.png (deflated 18%)
#   adding: processed_signatures/41/proc_forgeries_41_6.png (deflated 21%)
#   adding: processed_signatures/41/proc_forgeries_41_16.png (deflated 20%)
#   adding: processed_signatures/41/proc_forgeries_41_11.png (deflated 22%)
#   adding: processed_signatures/41/proc_forgeries_41_14.png (deflated 22%)
#   adding: processed_signatures/41/proc_original_41_23.png (deflated 17%)
#   adding: processed_signatures/41/proc_forgeries_41_8.png (deflated 22%)
#   adding: processed_signatures/41/proc_original_41_4.png (deflated 17%)
#   adding: processed_signatures/13/ (stored 0%)
#   adding: processed_signatures/13/proc_original_13_8.png (deflated 18%)
#   adding: processed_signatures/13/proc_forgeries_13_10.png (deflated 19%)
#   adding: processed_signatures/13/proc_original_13_11.png (deflated 17%)
#   adding: processed_signatures/13/proc_forgeries_13_22.png (deflated 19%)
#   adding: processed_signatures/13/proc_original_13_6.png (deflated 18%)
#   adding: processed_signatures/13/proc_original_13_16.png (deflated 17%)
#   adding: processed_signatures/13/proc_forgeries_13_5.png (deflated 18%)
#   adding: processed_signatures/13/proc_forgeries_13_20.png (deflated 18%)
#   adding: processed_signatures/13/proc_original_13_24.png (deflated 18%)
#   adding: processed_signatures/13/proc_original_13_2.png (deflated 18%)
#   adding: processed_signatures/13/proc_forgeries_13_13.png (deflated 19%)
#   adding: processed_signatures/13/proc_original_13_10.png (deflated 18%)
#   adding: processed_signatures/13/proc_original_13_5.png (deflated 18%)
#   adding: processed_signatures/13/proc_forgeries_13_2.png (deflated 18%)
#   adding: processed_signatures/13/proc_original_13_17.png (deflated 18%)
#   adding: processed_signatures/13/proc_original_13_7.png (deflated 18%)
#   adding: processed_signatures/13/proc_original_13_4.png (deflated 18%)
#   adding: processed_signatures/13/proc_original_13_22.png (deflated 17%)
#   adding: processed_signatures/13/proc_forgeries_13_23.png (deflated 19%)
#   adding: processed_signatures/13/proc_original_13_14.png (deflated 18%)
#   adding: processed_signatures/13/proc_forgeries_13_19.png (deflated 19%)
#   adding: processed_signatures/13/proc_forgeries_13_9.png (deflated 18%)
#   adding: processed_signatures/13/proc_forgeries_13_1.png (deflated 18%)
#   adding: processed_signatures/13/proc_forgeries_13_21.png (deflated 19%)
# ...
#   adding: processed_signatures/24/proc_original_24_7.png (deflated 20%)
#   adding: processed_signatures/24/proc_original_24_24.png (deflated 17%)
#   adding: processed_signatures/24/proc_forgeries_24_12.png (deflated 19%)
#   adding: processed_signatures/24/proc_original_24_21.png (deflated 18%)
#   adding: processed_signatures/24/proc_original_24_11.png (deflated 20%)
#   adding: processed_signatures/24/proc_original_24_22.png (deflated 19%)
#   adding: processed_signatures/24/proc_forgeries_24_9.png (deflated 19%)
#   adding: processed_signatures/24/proc_original_24_2.png (deflated 19%)
#   adding: processed_signatures/24/proc_forgeries_24_13.png (deflated 19%)
#   adding: processed_signatures/24/proc_forgeries_24_20.png (deflated 20%)
#   adding: processed_signatures/24/proc_forgeries_24_10.png (deflated 19%)
#   adding: processed_signatures/24/proc_original_24_9.png (deflated 19%)
#   adding: processed_signatures/24/proc_forgeries_24_19.png (deflated 20%)
#   adding: processed_signatures/24/proc_original_24_15.png (deflated 18%)
#   adding: processed_signatures/24/proc_original_24_12.png (deflated 19%)
#   adding: processed_signatures/24/proc_forgeries_24_4.png (deflated 19%)
#   adding: processed_signatures/24/proc_forgeries_24_18.png (deflated 18%)
#   adding: processed_signatures/24/proc_original_24_18.png (deflated 18%)
#   adding: processed_signatures/24/proc_forgeries_24_16.png (deflated 19%)
#   adding: processed_signatures/24/proc_original_24_3.png (deflated 18%)
#   adding: processed_signatures/24/proc_forgeries_24_24.png (deflated 19%)
#   adding: processed_signatures/24/proc_original_24_10.png (deflated 19%)
#   adding: processed_signatures/24/proc_forgeries_24_6.png (deflated 20%)
#   adding: processed_signatures/24/proc_original_24_1.png (deflated 19%)
#   adding: processed_signatures/24/proc_original_24_16.png (deflated 19%)
#   adding: processed_signatures/38/ (stored 0%)
#   adding: processed_signatures/38/proc_forgeries_38_14.png (deflated 24%)
#   adding: processed_signatures/38/proc_original_38_12.png (deflated 20%)
#   adding: processed_signatures/38/proc_forgeries_38_5.png (deflated 24%)
#   adding: processed_signatures/38/proc_original_38_20.png (deflated 20%)
#   adding: processed_signatures/38/proc_forgeries_38_13.png (deflated 25%)
#   adding: processed_signatures/38/proc_original_38_24.png (deflated 19%)
#   adding: processed_signatures/38/proc_original_38_19.png (deflated 18%)
#   adding: processed_signatures/38/proc_forgeries_38_7.png (deflated 25%)
#   adding: processed_signatures/38/proc_original_38_7.png (deflated 19%)
#   adding: processed_signatures/38/proc_original_38_5.png (deflated 19%)
#   adding: processed_signatures/38/proc_forgeries_38_15.png (deflated 25%)
#   adding: processed_signatures/38/proc_forgeries_38_12.png (deflated 25%)
#   adding: processed_signatures/38/proc_forgeries_38_18.png (deflated 25%)
#   adding: processed_signatures/38/proc_forgeries_38_21.png (deflated 25%)
#   adding: processed_signatures/38/proc_original_38_18.png (deflated 17%)
#   adding: processed_signatures/38/proc_original_38_9.png (deflated 19%)
#   adding: processed_signatures/38/proc_original_38_15.png (deflated 19%)
#   adding: processed_signatures/38/proc_original_38_1.png (deflated 19%)
#   adding: processed_signatures/38/proc_forgeries_38_2.png (deflated 24%)
#   adding: processed_signatures/38/proc_forgeries_38_23.png (deflated 26%)
#   adding: processed_signatures/38/proc_forgeries_38_3.png (deflated 26%)
#   adding: processed_signatures/38/proc_original_38_2.png (deflated 19%)
#   adding: processed_signatures/38/proc_original_38_6.png (deflated 19%)
#   adding: processed_signatures/38/proc_original_38_10.png (deflated 18%)
#   adding: processed_signatures/38/proc_forgeries_38_22.png (deflated 26%)
#   adding: processed_signatures/38/proc_original_38_22.png (deflated 20%)
#   adding: processed_signatures/38/proc_forgeries_38_19.png (deflated 25%)
#   adding: processed_signatures/38/proc_original_38_4.png (deflated 19%)
#   adding: processed_signatures/38/proc_original_38_14.png (deflated 19%)
#   adding: processed_signatures/38/proc_original_38_16.png (deflated 18%)
#   adding: processed_signatures/38/proc_forgeries_38_6.png (deflated 24%)
#   adding: processed_signatures/38/proc_forgeries_38_24.png (deflated 26%)
#   adding: processed_signatures/38/proc_original_38_11.png (deflated 21%)
#   adding: processed_signatures/38/proc_forgeries_38_17.png (deflated 25%)
#   adding: processed_signatures/38/proc_original_38_17.png (deflated 20%)
#   adding: processed_signatures/38/proc_original_38_21.png (deflated 20%)
#   adding: processed_signatures/38/proc_forgeries_38_8.png (deflated 23%)
#   adding: processed_signatures/38/proc_forgeries_38_11.png (deflated 25%)
#   adding: processed_signatures/38/proc_forgeries_38_9.png (deflated 25%)
#   adding: processed_signatures/38/proc_original_38_13.png (deflated 18%)
#   adding: processed_signatures/38/proc_original_38_3.png (deflated 20%)
#   adding: processed_signatures/38/proc_forgeries_38_10.png (deflated 25%)
#   adding: processed_signatures/38/proc_forgeries_38_4.png (deflated 26%)
#   adding: processed_signatures/38/proc_forgeries_38_16.png (deflated 25%)
#   adding: processed_signatures/38/proc_original_38_23.png (deflated 20%)
#   adding: processed_signatures/38/proc_forgeries_38_1.png (deflated 25%)
#   adding: processed_signatures/38/proc_original_38_8.png (deflated 20%)
#   adding: processed_signatures/38/proc_forgeries_38_20.png (deflated 25%)
#   adding: processed_signatures/52/ (stored 0%)
#   adding: processed_signatures/52/proc_original_52_2.png (deflated 21%)
#   adding: processed_signatures/52/proc_forgeries_52_7.png (deflated 23%)
#   adding: processed_signatures/52/proc_forgeries_52_9.png (deflated 21%)
#   adding: processed_signatures/52/proc_original_52_5.png (deflated 21%)
#   adding: processed_signatures/52/proc_original_52_23.png (deflated 21%)
#   adding: processed_signatures/52/proc_forgeries_52_18.png (deflated 22%)
#   adding: processed_signatures/52/proc_forgeries_52_20.png (deflated 22%)
#   adding: processed_signatures/52/proc_forgeries_52_6.png (deflated 20%)
#   adding: processed_signatures/52/proc_original_52_4.png (deflated 21%)
#   adding: processed_signatures/52/proc_forgeries_52_2.png (deflated 23%)
#   adding: processed_signatures/52/proc_original_52_24.png (deflated 21%)
#   adding: processed_signatures/52/proc_original_52_11.png (deflated 21%)
#   adding: processed_signatures/52/proc_original_52_13.png (deflated 20%)
#   adding: processed_signatures/52/proc_forgeries_52_13.png (deflated 21%)
#   adding: processed_signatures/52/proc_forgeries_52_8.png (deflated 22%)
#   adding: processed_signatures/52/proc_forgeries_52_17.png (deflated 22%)
#   adding: processed_signatures/52/proc_original_52_18.png (deflated 21%)
#   adding: processed_signatures/52/proc_original_52_12.png (deflated 21%)
#   adding: processed_signatures/52/proc_forgeries_52_4.png (deflated 23%)
#   adding: processed_signatures/52/proc_original_52_16.png (deflated 21%)
#   adding: processed_signatures/52/proc_forgeries_52_15.png (deflated 23%)
#   adding: processed_signatures/52/proc_forgeries_52_24.png (deflated 22%)
#   adding: processed_signatures/52/proc_forgeries_52_19.png (deflated 22%)
#   adding: processed_signatures/52/proc_forgeries_52_16.png (deflated 21%)
#   adding: processed_signatures/52/proc_forgeries_52_1.png (deflated 23%)
#   adding: processed_signatures/52/proc_forgeries_52_10.png (deflated 24%)
#   adding: processed_signatures/52/proc_original_52_8.png (deflated 20%)
#   adding: processed_signatures/52/proc_original_52_21.png (deflated 20%)
#   adding: processed_signatures/52/proc_original_52_1.png (deflated 21%)
#   adding: processed_signatures/52/proc_forgeries_52_5.png (deflated 23%)
#   adding: processed_signatures/52/proc_forgeries_52_11.png (deflated 21%)
#   adding: processed_signatures/52/proc_forgeries_52_12.png (deflated 21%)
#   adding: processed_signatures/52/proc_forgeries_52_22.png (deflated 21%)
#   adding: processed_signatures/52/proc_original_52_20.png (deflated 21%)
#   adding: processed_signatures/52/proc_original_52_3.png (deflated 20%)
#   adding: processed_signatures/52/proc_original_52_22.png (deflated 23%)
#   adding: processed_signatures/52/proc_original_52_15.png (deflated 21%)
#   adding: processed_signatures/52/proc_forgeries_52_23.png (deflated 22%)
#   adding: processed_signatures/52/proc_original_52_17.png (deflated 21%)
#   adding: processed_signatures/52/proc_original_52_9.png (deflated 20%)
#   adding: processed_signatures/52/proc_forgeries_52_21.png (deflated 21%)
#   adding: processed_signatures/52/proc_original_52_19.png (deflated 20%)
#   adding: processed_signatures/52/proc_original_52_7.png (deflated 21%)
#   adding: processed_signatures/52/proc_forgeries_52_14.png (deflated 23%)
#   adding: processed_signatures/52/proc_forgeries_52_3.png (deflated 21%)
#   adding: processed_signatures/52/proc_original_52_10.png (deflated 22%)
#   adding: processed_signatures/52/proc_original_52_6.png (deflated 20%)
#   adding: processed_signatures/52/proc_original_52_14.png (deflated 20%)
#   adding: processed_signatures/2/ (stored 0%)
#   adding: processed_signatures/2/proc_original_2_17.png (deflated 16%)
#   adding: processed_signatures/2/proc_forgeries_2_9.png (deflated 21%)
#   adding: processed_signatures/2/proc_original_2_11.png (deflated 19%)
#   adding: processed_signatures/2/proc_forgeries_2_16.png (deflated 21%)
#   adding: processed_signatures/2/proc_original_2_18.png (deflated 16%)
#   adding: processed_signatures/2/proc_forgeries_2_3.png (deflated 20%)
#   adding: processed_signatures/2/proc_original_2_5.png (deflated 17%)
#   adding: processed_signatures/2/proc_forgeries_2_19.png (deflated 21%)
#   adding: processed_signatures/2/proc_original_2_1.png (deflated 17%)
#   adding: processed_signatures/2/proc_original_2_14.png (deflated 15%)
#   adding: processed_signatures/2/proc_original_2_8.png (deflated 17%)
#   adding: processed_signatures/2/proc_original_2_16.png (deflated 16%)
#   adding: processed_signatures/2/proc_forgeries_2_21.png (deflated 21%)
#   adding: processed_signatures/2/proc_forgeries_2_12.png (deflated 21%)
#   adding: processed_signatures/2/proc_original_2_21.png (deflated 16%)
#   adding: processed_signatures/2/proc_forgeries_2_17.png (deflated 18%)
#   adding: processed_signatures/2/proc_forgeries_2_2.png (deflated 19%)
#   adding: processed_signatures/2/proc_forgeries_2_18.png (deflated 20%)
#   adding: processed_signatures/2/proc_forgeries_2_4.png (deflated 19%)
#   adding: processed_signatures/2/proc_original_2_15.png (deflated 17%)
#   adding: processed_signatures/2/proc_forgeries_2_11.png (deflated 19%)
#   adding: processed_signatures/2/proc_forgeries_2_20.png (deflated 20%)
#   adding: processed_signatures/2/proc_forgeries_2_13.png (deflated 21%)
#   adding: processed_signatures/2/proc_original_2_12.png (deflated 16%)
#   adding: processed_signatures/2/proc_forgeries_2_14.png (deflated 19%)
#   adding: processed_signatures/2/proc_original_2_24.png (deflated 16%)
#   adding: processed_signatures/2/proc_original_2_10.png (deflated 17%)
#   adding: processed_signatures/2/proc_original_2_7.png (deflated 17%)
#   adding: processed_signatures/2/proc_original_2_2.png (deflated 17%)
#   adding: processed_signatures/2/proc_original_2_23.png (deflated 17%)
#   adding: processed_signatures/2/proc_forgeries_2_22.png (deflated 21%)
#   adding: processed_signatures/2/proc_original_2_9.png (deflated 16%)
#   adding: processed_signatures/2/proc_original_2_22.png (deflated 16%)
#   adding: processed_signatures/2/proc_forgeries_2_15.png (deflated 20%)
#   adding: processed_signatures/2/proc_original_2_3.png (deflated 17%)
#   adding: processed_signatures/2/proc_forgeries_2_24.png (deflated 20%)
#   adding: processed_signatures/2/proc_forgeries_2_23.png (deflated 20%)
#   adding: processed_signatures/2/proc_forgeries_2_6.png (deflated 22%)
#   adding: processed_signatures/2/proc_forgeries_2_10.png (deflated 22%)
#   adding: processed_signatures/2/proc_original_2_13.png (deflated 17%)
#   adding: processed_signatures/2/proc_original_2_6.png (deflated 18%)
#   adding: processed_signatures/2/proc_forgeries_2_1.png (deflated 20%)
#   adding: processed_signatures/2/proc_original_2_19.png (deflated 16%)
#   adding: processed_signatures/2/proc_original_2_4.png (deflated 18%)
#   adding: processed_signatures/2/proc_forgeries_2_7.png (deflated 21%)
#   adding: processed_signatures/2/proc_forgeries_2_5.png (deflated 18%)
#   adding: processed_signatures/2/proc_forgeries_2_8.png (deflated 19%)
#   adding: processed_signatures/2/proc_original_2_20.png (deflated 17%)
#   adding: processed_signatures/39/ (stored 0%)
#   adding: processed_signatures/39/proc_forgeries_39_12.png (deflated 24%)
#   adding: processed_signatures/39/proc_original_39_12.png (deflated 19%)
#   adding: processed_signatures/39/proc_original_39_7.png (deflated 19%)
#   adding: processed_signatures/39/proc_original_39_23.png (deflated 19%)
#   adding: processed_signatures/39/proc_forgeries_39_18.png (deflated 25%)
#   adding: processed_signatures/39/proc_original_39_2.png (deflated 19%)
#   adding: processed_signatures/39/proc_original_39_19.png (deflated 19%)
#   adding: processed_signatures/39/proc_original_39_4.png (deflated 19%)
#   adding: processed_signatures/39/proc_forgeries_39_14.png (deflated 22%)
#   adding: processed_signatures/39/proc_forgeries_39_4.png (deflated 22%)
#   adding: processed_signatures/39/proc_forgeries_39_16.png (deflated 24%)
#   adding: processed_signatures/39/proc_original_39_9.png (deflated 19%)
#   adding: processed_signatures/39/proc_original_39_15.png (deflated 20%)
#   adding: processed_signatures/39/proc_forgeries_39_7.png (deflated 23%)
#   adding: processed_signatures/39/proc_original_39_24.png (deflated 20%)
#   adding: processed_signatures/39/proc_forgeries_39_23.png (deflated 23%)
#   adding: processed_signatures/39/proc_original_39_20.png (deflated 20%)
#   adding: processed_signatures/39/proc_forgeries_39_6.png (deflated 25%)
#   adding: processed_signatures/39/proc_forgeries_39_22.png (deflated 24%)
#   adding: processed_signatures/39/proc_original_39_22.png (deflated 20%)
#   adding: processed_signatures/39/proc_forgeries_39_8.png (deflated 23%)
#   adding: processed_signatures/39/proc_forgeries_39_2.png (deflated 24%)
#   adding: processed_signatures/39/proc_forgeries_39_5.png (deflated 22%)
#   adding: processed_signatures/39/proc_original_39_1.png (deflated 19%)
#   adding: processed_signatures/39/proc_forgeries_39_3.png (deflated 23%)
#   adding: processed_signatures/39/proc_forgeries_39_20.png (deflated 21%)
#   adding: processed_signatures/39/proc_original_39_3.png (deflated 19%)
#   adding: processed_signatures/39/proc_forgeries_39_13.png (deflated 25%)
#   adding: processed_signatures/39/proc_original_39_16.png (deflated 19%)
#   adding: processed_signatures/39/proc_forgeries_39_9.png (deflated 26%)
#   adding: processed_signatures/39/proc_original_39_18.png (deflated 19%)
#   adding: processed_signatures/39/proc_forgeries_39_15.png (deflated 23%)
#   adding: processed_signatures/39/proc_original_39_6.png (deflated 20%)
#   adding: processed_signatures/39/proc_forgeries_39_19.png (deflated 25%)
#   adding: processed_signatures/39/proc_original_39_13.png (deflated 20%)
#   adding: processed_signatures/39/proc_original_39_10.png (deflated 21%)
#   adding: processed_signatures/39/proc_forgeries_39_17.png (deflated 22%)
#   adding: processed_signatures/39/proc_original_39_8.png (deflated 19%)
#   adding: processed_signatures/39/proc_original_39_21.png (deflated 20%)
#   adding: processed_signatures/39/proc_forgeries_39_24.png (deflated 24%)
#   adding: processed_signatures/39/proc_original_39_11.png (deflated 20%)
#   adding: processed_signatures/39/proc_forgeries_39_11.png (deflated 21%)
#   adding: processed_signatures/39/proc_original_39_14.png (deflated 21%)
#   adding: processed_signatures/39/proc_forgeries_39_10.png (deflated 23%)
#   adding: processed_signatures/39/proc_forgeries_39_1.png (deflated 23%)
#   adding: processed_signatures/39/proc_original_39_17.png (deflated 19%)
#   adding: processed_signatures/39/proc_forgeries_39_21.png (deflated 24%)
#   adding: processed_signatures/39/proc_original_39_5.png (deflated 19%)

# %% [markdown]
# Prepare data
#
# - Below, the approach described in the paper is used. There are several other ways to make pairs and select instances.

# %%
import itertools
def make_pairs(images, labels):
  """
  images: ~numpy.array
    Images in the dataset
  labels: ~numpy.array
    Labels

  """
  assert len(images) == len(labels)

  # Class 1: Original, Class 0: Forgeries.
  # Positive samples.
  o_combs = list(itertools.combinations(images[labels==1], 2))

  # Negative samples.
  of_combs = []
  for image1 in images[labels==1]:
    for image0 in images[labels==0]:
      of_combs.append([image1, image0])

  # Select random 276 elements from (ordinary, forgery) pair out of the 576 elements to handle imbalance.
  of_combs = random.sample(of_combs, 276)

  pair_images = o_combs + of_combs
  pair_labels = [1] * len(o_combs) + [0] * len(of_combs)

  return (np.array(pair_images), np.array(pair_labels))

# %%
def train_test(root_dir, k=50):
  """
  root_dir: The base directory containing the processed images.
  k: No. of signers to use for training. For the CEDAR database, k = 50.

  Format of root_dir:
  ------
  processed_signatures/
    1/
      proc_*.png
    2/
      proc_*.png
    ..
    55/
      ...
  """
  train_images = []
  train_labels = []
  test_images = []
  test_labels = []

  trainx = []
  trainy = []
  testx = []
  testy = []

  all_signers = os.listdir(root_dir)
  train_signers = np.random.choice(all_signers, k, replace=False)
  test_signers = list(set(all_signers) - set(train_signers))

  for signer in train_signers:
    current_signer_imagenames = os.listdir(os.path.join(root_dir, signer))
    current_signer_images = np.array(
        [cv2.imread(os.path.join(root_dir, signer, img), 0) for img in current_signer_imagenames]
    )
    current_signer_labels = np.array(
        [int(img.split("_")[1] == "original") for img in current_signer_imagenames]
    )
    current_pair_images, current_pair_labels = make_pairs(current_signer_images, current_signer_labels)
    current_pair_images
    trainx.append(current_pair_images)
    trainy.append(current_pair_labels)
    # for image in os.listdir(os.path.join(root_dir, signer)):
    #   img = cv2.imread(os.path.join(root_dir, signer, image), 0)
    #   train_images.append(img)
    #   if image.split("_")[1] == "forgeries":
    #     train_labels.append(0)
    #   elif image.split("_")[1] == "original":
    #     train_labels.append(1)

  for signer in test_signers:
    current_signer_imagenames = os.listdir(os.path.join(root_dir, signer))
    current_signer_images = np.array(
        [cv2.imread(os.path.join(root_dir, signer, img), 0) for img in current_signer_imagenames]
    )
    current_signer_labels = np.array(
        [int(img.split("_")[1] == "original") for img in current_signer_imagenames]
    )
    current_pair_images, current_pair_labels = make_pairs(current_signer_images, current_signer_labels)
    testx.append(current_pair_images)
    testy.append(current_pair_labels)
    # for image in os.listdir(os.path.join(root_dir, signer)):
    #   img = cv2.imread(os.path.join(root_dir, signer, image), 0)
    #   test_images.append(img)
    #   if image.split("_")[1] == "forgeries":
    #     test_labels.append(0)
    #   elif image.split("_")[1] == "original":
    #     test_labels.append(1)

  trainx = np.array(trainx).reshape(-1, 2, 220, 155)
  testx = np.array(testx).reshape(-1, 2, 220, 155)
  trainy = np.array(trainy).reshape(-1, 1)
  testy = np.array(testy).reshape(-1, 1)

  return trainx, np.array(trainy), testx, np.array(testy)

trainx, trainy, testx, testy = train_test("processed_signatures")

# %%
trainx.shape, trainy.shape, testx.shape, testy.shape
# Out:
# ((27600, 2, 220, 155), (27600, 1), (2760, 2, 220, 155), (2760, 1))

# %%
import random
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset
from torch.utils.data.sampler import SubsetRandomSampler

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda:0'

# %%
trainx.shape
# Out:
# (27600, 2, 220, 155)

# %%
trainy.shape
# Out:
# (27600, 1)

# %%
class SignatureVerificationDataset(Dataset):
  def __init__(self, images, labels, transforms=None):
    self.transforms = transforms
    self.images = images
    self.labels = labels
  
  def __getitem__(self, idx):
    img0 = self.images[idx][0]
    img1 = self.images[idx][1]
    
    if transforms:
      img0 = self.transforms(img0)
      img1 = self.transforms(img1)

    return img0, img1, self.labels[idx]

  def __len__(self):
      return self.images.shape[0]

# %%
# folder_dataset = datasets.ImageFolder(root="processed_signatures")

# Other transformations were done during pre-processing.
transforms_ = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.449], [0.226]),
])
train_signature_dataset = SignatureVerificationDataset(trainx, trainy, transforms=transforms_)

# %%
def imshow(img):
  plt.figure(figsize=(20, 6))
  img = img.permute(1, 2, 0)
  img = img.numpy()
  plt.imshow((img * 255).astype(np.uint8))
  plt.show()

# %%
train_loader = DataLoader(
    train_signature_dataset,
    shuffle=True,
    num_workers=2,
    batch_size=8
)
dataiter = iter(train_loader)

example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0], example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[0]
#  [1]
#  [1]
#  [0]
#  [0]
#  [0]
#  [1]
#  [1]]

# %%
# # Split datasets
# train_test_split = 0.8  # 80% train, 20% test.
# valid_train_split = 0.2  # 20% valid, 80% train.

# dataset_size = len(signature_dataset)
# indices = list(range(dataset_size))
# np.random.shuffle(indices)  # Random shuffling

# test_split = int(np.floor((1-train_test_split)*dataset_size))
# test_indices, train_indices = indices[:test_split], indices[test_split:]

# train_sampler = SubsetRandomSampler(train_indices)
# test_sampler = SubsetRandomSampler(test_indices)

# train_size = len(train_indices)
# valid_split = int(np.floor(valid_train_split*train_size))
# valid_indices = train_indices[:valid_split]

# valid_sampler = SubsetRandomSampler(valid_indices)

# %%
test_signature_dataset = SignatureVerificationDataset(testx, testy, transforms=transforms_)
test_loader = DataLoader(
    test_signature_dataset,
    shuffle=True,
    num_workers=2,
    batch_size=1,
)

# %%
# batch_size = 8
# num_workers = 2

# train_loader = torch.utils.data.DataLoader(
#     signature_dataset, batch_size=batch_size, sampler=train_sampler, num_workers=num_workers
# )
# valid_loader = torch.utils.data.DataLoader(
#     signature_dataset, batch_size=batch_size, sampler=valid_sampler, num_workers=num_workers
# )

# # Since we compare each test image separately, batch_size must be one.
# test_loader = torch.utils.data.DataLoader(
#     signature_dataset, batch_size=1, sampler=test_sampler, num_workers=num_workers
# )

# types = ["train", "valid", "test"]
# samplers = {"train": train_sampler, "valid": valid_sampler, "test": test_sampler}
# dataloaders = {x: torch.utils.data.DataLoader(
#                 signature_dataset, batch_size=batch_size, sampler=samplers[x], num_workers=num_workers) for x in types
#               }

# %%
"""
From https://discuss.pytorch.org/t/linear-layer-input-neurons-number-calculation-after-conv2d/28659/2:
> In PyTorch, image data is expected to have the shape [batch_size, channel, height, width].
"""
class SignatureVerificationNetwork(nn.Module):
  def __init__(self):
    super().__init__()
    
    # No. of kernels = No. of out channels (each channel is convolved independently).
    self.conv1 = nn.Conv2d(in_channels=1, out_channels=96, kernel_size=11, stride=1)
    self.conv2 = nn.Conv2d(in_channels=96, out_channels=256, kernel_size=5, stride=1, padding=2)
    self.conv3 = nn.Conv2d(in_channels=256, out_channels=384, kernel_size=3, stride=1, padding=1)
    self.conv4 = nn.Conv2d(in_channels=384, out_channels=256, kernel_size=3, stride=1, padding=1)
    self.fc1 = nn.Linear(108800, 1024)
    self.fc2 = nn.Linear(1024, 128)
    self.lrn = nn.LocalResponseNorm(size=5, alpha=1e-4, beta=0.75, k=2)
    self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2)
    self.dropout1 = nn.Dropout2d(0.3)
    self.dropout2 = nn.Dropout2d(0.3)

    self.conv_relu_pool_norm = nn.Sequential(
        nn.Conv2d(in_channels=1, out_channels=96, kernel_size=11, stride=1),
        nn.ReLU(inplace=True),
        nn.LocalResponseNorm(size=5, alpha=1e-4, beta=0.75, k=2),
        nn.MaxPool2d(kernel_size=3, stride=2),

        nn.Conv2d(in_channels=96, out_channels=256, kernel_size=5, stride=1, padding=2),
        nn.ReLU(inplace=True),
        nn.LocalResponseNorm(size=5, alpha=1e-4, beta=0.75, k=2),
        nn.MaxPool2d(kernel_size=3, stride=2),
        nn.Dropout2d(0.3),

        nn.Conv2d(in_channels=256, out_channels=384, kernel_size=3, stride=1, padding=1),
        nn.ReLU(inplace=True),
        nn.Conv2d(in_channels=384, out_channels=256, kernel_size=3, stride=1, padding=1),
        nn.ReLU(inplace=True),
        
        nn.MaxPool2d(kernel_size=3, stride=2),
        nn.Dropout2d(0.3),
    )
    self.fc = nn.Sequential(
        nn.Linear(108800, 1024),
        nn.ReLU(inplace=True),
        nn.Dropout(0.5),
        nn.Linear(1024, 128),
        nn.ReLU(inplace=True),
    )

  def forward_single(self, x):
    x = self.conv_relu_pool_norm(x)
    x = x.view(x.size()[0], -1)
    x = self.fc(x)
    return x

  def forward(self, x1, x2):
    out1 = self.forward_single(x1)
    out2 = self.forward_single(x2)

    return out1, out2

svn = SignatureVerificationNetwork()
svn = svn.to(device)

# %%
class ContrastiveLoss(torch.nn.Module):
  def __init__(self, margin=1.0):  # Margin is set to 1. as per the paper.
    super(ContrastiveLoss, self).__init__()
    self.margin = margin

  def forward(self, output1, output2, label):
    euclidean_distance = F.pairwise_distance(output1, output2, keepdim=True)
    loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                  (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))
    return loss_contrastive

# %%
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler

criterion = ContrastiveLoss()  # Use above-defined custom loss function.
optimizer = optim.RMSprop(svn.parameters(), lr=1e-4, momentum=0.9, weight_decay=0.0005)

# lr_lambda = lambda epoch: 0.1  # TODO: Verify if this follows paper.
# scheduler = lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lr_lambda)

scheduler = lr_scheduler.StepLR(optimizer, step_size=8)

epochs = 4

# %%
# Utility
def show_plot(iteration, loss):
    plt.plot(iteration, loss)
    plt.show()

# %%
counter = []
iteration_number = 0
loss_history = [] 

svn.train()
for epoch in range(epochs):
  for i, data in enumerate(train_loader, 0):
    img0, img1, label = data
    img0, img1, label = img0.to(device), img1.to(device), label.to(device)
    optimizer.zero_grad()
    output1, output2 = svn(img0, img1)
    loss_contrastive = criterion(output1, output2, label)
    loss_contrastive.backward()
    optimizer.step()
    if i % 20 == 0 :
      print("Epoch number {}\n Current loss {}\n".format(epoch, loss_contrastive.item()))
      iteration_number += 20
      counter.append(iteration_number)
      loss_history.append(loss_contrastive.item())
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch number 0
#  Current loss 0.6151443719863892
#
# Epoch number 0
#  Current loss 5.1651387214660645
#
# Epoch number 0
#  Current loss 0.3749915361404419
#
# Epoch number 0
#  Current loss 0.5558832883834839
#
# Epoch number 0
#  Current loss 0.38589972257614136
#
# Epoch number 0
#  Current loss 0.4999886751174927
#
# Epoch number 0
#  Current loss 0.4999886751174927
#
# Epoch number 0
#  Current loss 0.6184526085853577
#
# Epoch number 0
#  Current loss 0.4999886751174927
#
# Epoch number 0
#  Current loss 0.3752906024456024
#
# Epoch number 0
#  Current loss 0.24999433755874634
#
# Epoch number 0
#  Current loss 0.4225579798221588
#
# Epoch number 0
#  Current loss 0.45633092522621155
#
# Epoch number 0
#  Current loss 0.8749802112579346
#
# Epoch number 0
#  Current loss 0.4999886751174927
#
# Epoch number 0
#  Current loss 0.2504141628742218
#
# Epoch number 0
#  Current loss 1.367152452468872
#
# Epoch number 0
#  Current loss 0.6585968732833862
#
# Epoch number 0
#  Current loss 0.5446552634239197
#
# Epoch number 0
#  Current loss 0.4833500385284424
#
# Epoch number 0
#  Current loss 0.3286771774291992
#
# Epoch number 0
#  Current loss 0.48561418056488037
#
# Epoch number 0
#  Current loss 0.5365728139877319
#
# Epoch number 0
#  Current loss 0.06468931585550308
#
# Epoch number 0
#  Current loss 0.6563206911087036
#
# Epoch number 0
#  Current loss 0.4167020916938782
#
# Epoch number 0
#  Current loss 0.3276064991950989
#
# Epoch number 0
#  Current loss 0.3012966811656952
#
# Epoch number 0
#  Current loss 0.5632098317146301
#
# Epoch number 0
#  Current loss 0.45966413617134094
#
# Epoch number 0
#  Current loss 0.232491135597229
#
# Epoch number 0
#  Current loss 0.4109960198402405
#
# Epoch number 0
#  Current loss 0.36695539951324463
#
# Epoch number 0
#  Current loss 0.19825521111488342
#
# Epoch number 0
#  Current loss 0.21019692718982697
#
# Epoch number 0
#  Current loss 0.43848785758018494
#
# Epoch number 0
#  Current loss 0.3346870243549347
#
# Epoch number 0
#  Current loss 0.23737148940563202
#
# Epoch number 0
#  Current loss 0.19090107083320618
#
# Epoch number 0
#  Current loss 0.37596869468688965
#
# Epoch number 0
#  Current loss 0.30006277561187744
#
# Epoch number 0
#  Current loss 0.1571284532546997
#
# Epoch number 0
#  Current loss 0.46759000420570374
#
# Epoch number 0
#  Current loss 0.4999886751174927
#
# Epoch number 0
#  Current loss 0.4999886751174927
#
# Epoch number 0
#  Current loss 0.4999886751174927
#
# Epoch number 0
#  Current loss 0.749983012676239
#
# Epoch number 0
#  Current loss 0.4999886751174927
#
# Epoch number 0
#  Current loss 0.4999886751174927
#
# Epoch number 0
#  Current loss 0.12499716877937317
#
# Epoch number 0
#  Current loss 0.24999433755874634
#
# Epoch number 0
#  Current loss 0.5005246996879578
#
# Epoch number 0
#  Current loss 0.8749802112579346
#
# Epoch number 0
#  Current loss 0.5267418622970581
#
# Epoch number 0
#  Current loss 0.4999886751174927
#
# Epoch number 0
#  Current loss 0.6668107509613037
#
# Epoch number 0
#  Current loss 0.3749915063381195
#
# Epoch number 0
#  Current loss 0.4999886751174927
#
# Epoch number 0
#  Current loss 0.4999886751174927
#
# Epoch number 0
#  Current loss 0.3749915063381195
#
# Epoch number 0
#  Current loss 0.24999433755874634
#
# Epoch number 0
#  Current loss 0.6249858140945435
#
# Epoch number 0
#  Current loss 0.6249858140945435
#
# Epoch number 0
#  Current loss 0.3749915063381195
#
# Epoch number 0
#  Current loss 0.3749915063381195
#
# Epoch number 0
#  Current loss 0.24999433755874634
#
# Epoch number 0
#  Current loss 0.749983012676239
#
# Epoch number 0
#  Current loss 0.39222779870033264
#
# Epoch number 0
#  Current loss 0.5284000635147095
#
# Epoch number 0
#  Current loss 0.07121656090021133
#
# Epoch number 0
#  Current loss 0.4454626441001892
#
# Epoch number 0
#  Current loss 0.1930500566959381
#
# Epoch number 0
#  Current loss 0.2466663271188736
#
# Epoch number 0
#  Current loss 0.36432433128356934
#
# Epoch number 0
#  Current loss 0.2545676827430725
#
# Epoch number 0
#  Current loss 0.2425748109817505
#
# Epoch number 0
#  Current loss 0.13222667574882507
#
# Epoch number 0
#  Current loss 0.48998796939849854
#
# Epoch number 0
#  Current loss 0.38529229164123535
#
# Epoch number 0
#  Current loss 0.40410083532333374
#
# Epoch number 0
#  Current loss 0.39909088611602783
#
# Epoch number 0
#  Current loss 1.1822686195373535
#
# Epoch number 0
#  Current loss 0.38057440519332886
#
# Epoch number 0
#  Current loss 0.2889987826347351
#
# Epoch number 0
#  Current loss 0.4892607629299164
#
# Epoch number 0
#  Current loss 0.39236658811569214
#
# Epoch number 0
#  Current loss 0.3497304320335388
#
# Epoch number 0
#  Current loss 0.33274173736572266
#
# Epoch number 0
#  Current loss 0.33090323209762573
#
# Epoch number 0
#  Current loss 0.38244158029556274
#
# Epoch number 0
#  Current loss 0.5933390259742737
#
# Epoch number 0
#  Current loss 0.5207509994506836
#
# Epoch number 0
#  Current loss 0.3044399917125702
#
# Epoch number 0
#  Current loss 0.23814867436885834
#
# Epoch number 0
#  Current loss 0.3480244278907776
#
# Epoch number 0
#  Current loss 0.7016727924346924
#
# Epoch number 0
#  Current loss 4.650723934173584
#
# Epoch number 0
#  Current loss 0.3885175585746765
#
# Epoch number 0
#  Current loss 0.37972491979599
#
# Epoch number 0
#  Current loss 0.32603687047958374
#
# Epoch number 0
#  Current loss 0.33385148644447327
#
# Epoch number 0
#  Current loss 0.25677385926246643
#
# Epoch number 0
#  Current loss 0.269609272480011
#
# Epoch number 0
#  Current loss 0.40892279148101807
#
# Epoch number 0
#  Current loss 0.3543536067008972
#
# Epoch number 0
#  Current loss 0.3409826457500458
#
# Epoch number 0
#  Current loss 0.3028952479362488
#
# Epoch number 0
#  Current loss 0.3117784261703491
#
# Epoch number 0
#  Current loss 0.4377630352973938
#
# Epoch number 0
#  Current loss 0.2736162841320038
#
# Epoch number 0
#  Current loss 0.2866087555885315
#
# Epoch number 0
#  Current loss 0.4152573347091675
#
# Epoch number 0
#  Current loss 0.3882559537887573
#
# Epoch number 0
#  Current loss 0.17239072918891907
#
# Epoch number 0
#  Current loss 0.2514041066169739
#
# Epoch number 0
#  Current loss 0.23829962313175201
#
# Epoch number 0
#  Current loss 0.34663328528404236
#
# Epoch number 0
#  Current loss 0.3827141523361206
#
# Epoch number 0
#  Current loss 0.33909767866134644
#
# Epoch number 0
#  Current loss 0.2563512325286865
#
# Epoch number 0
#  Current loss 0.17391744256019592
#
# Epoch number 0
#  Current loss 0.4562363028526306
#
# Epoch number 0
#  Current loss 0.24602989852428436
#
# Epoch number 0
#  Current loss 0.3329762816429138
#
# Epoch number 0
#  Current loss 0.2874799370765686
#
# Epoch number 0
#  Current loss 0.2174018770456314
#
# Epoch number 0
#  Current loss 0.15921121835708618
#
# Epoch number 0
#  Current loss 0.303737610578537
#
# Epoch number 0
#  Current loss 0.353197306394577
#
# Epoch number 0
#  Current loss 0.4677906632423401
#
# Epoch number 0
#  Current loss 0.22960183024406433
#
# Epoch number 0
#  Current loss 0.2182655930519104
#
# Epoch number 0
#  Current loss 0.45931026339530945
#
# Epoch number 0
#  Current loss 0.28798907995224
#
# Epoch number 0
#  Current loss 0.21667712926864624
#
# Epoch number 0
#  Current loss 0.3046655058860779
#
# Epoch number 0
#  Current loss 0.47499600052833557
#
# Epoch number 0
#  Current loss 0.3839403986930847
#
# Epoch number 0
#  Current loss 0.22166933119297028
#
# Epoch number 0
#  Current loss 0.43749964237213135
#
# Epoch number 0
#  Current loss 0.4222186803817749
#
# Epoch number 0
#  Current loss 0.1631784588098526
#
# Epoch number 0
#  Current loss 0.3651150166988373
#
# Epoch number 0
#  Current loss 0.3593111038208008
#
# Epoch number 0
#  Current loss 0.25486117601394653
#
# Epoch number 0
#  Current loss 0.2577969431877136
#
# Epoch number 0
#  Current loss 0.21860046684741974
#
# Epoch number 0
#  Current loss 0.3132150173187256
#
# Epoch number 0
#  Current loss 0.27448636293411255
#
# Epoch number 0
#  Current loss 0.20330531895160675
#
# Epoch number 0
#  Current loss 0.16694006323814392
#
# Epoch number 0
#  Current loss 0.32987868785858154
#
# Epoch number 0
#  Current loss 0.2974624037742615
#
# Epoch number 0
#  Current loss 0.26614099740982056
#
# Epoch number 0
#  Current loss 0.3011505901813507
#
# Epoch number 0
#  Current loss 0.2711309790611267
#
# Epoch number 0
#  Current loss 0.3237232267856598
#
# Epoch number 0
#  Current loss 0.330061137676239
#
# Epoch number 0
#  Current loss 0.25708436965942383
#
# Epoch number 0
#  Current loss 0.2555338144302368
#
# Epoch number 0
#  Current loss 0.36250579357147217
#
# Epoch number 0
#  Current loss 0.2804209589958191
#
# Epoch number 0
#  Current loss 0.25305116176605225
#
# Epoch number 0
#  Current loss 0.25792834162712097
#
# Epoch number 0
#  Current loss 0.5082955360412598
#
# Epoch number 0
#  Current loss 0.19920481741428375
#
# Epoch number 0
#  Current loss 0.4263221025466919
#
# Epoch number 0
#  Current loss 0.21113792061805725
#
# Epoch number 0
#  Current loss 0.23095247149467468
#
# Epoch number 0
#  Current loss 0.15665492415428162
#
# Epoch number 0
#  Current loss 0.2278844714164734
#
# Epoch number 0
#  Current loss 0.2946719229221344
#
# Epoch number 0
#  Current loss 0.26494085788726807
#
# Epoch number 1
#  Current loss 0.29135042428970337
#
# Epoch number 1
#  Current loss 0.26996666193008423
#
# Epoch number 1
#  Current loss 0.3240639567375183
#
# Epoch number 1
#  Current loss 0.2237612009048462
#
# Epoch number 1
#  Current loss 0.2567504048347473
#
# Epoch number 1
#  Current loss 0.2554457187652588
#
# Epoch number 1
#  Current loss 0.22666016221046448
#
# Epoch number 1
#  Current loss 0.3427901268005371
#
# Epoch number 1
#  Current loss 0.28907161951065063
#
# Epoch number 1
#  Current loss 0.3599795997142792
#
# Epoch number 1
#  Current loss 0.2626466155052185
#
# Epoch number 1
#  Current loss 0.24762776494026184
#
# Epoch number 1
#  Current loss 0.2905385494232178
#
# Epoch number 1
#  Current loss 0.2520599067211151
#
# Epoch number 1
#  Current loss 0.32746216654777527
#
# Epoch number 1
#  Current loss 0.21879112720489502
#
# Epoch number 1
#  Current loss 0.3577602505683899
#
# Epoch number 1
#  Current loss 0.23807311058044434
#
# Epoch number 1
#  Current loss 0.3277361989021301
#
# Epoch number 1
#  Current loss 0.2123199850320816
#
# Epoch number 1
#  Current loss 0.22136038541793823
#
# Epoch number 1
#  Current loss 0.8953415155410767
#
# Epoch number 1
#  Current loss 0.43429213762283325
#
# Epoch number 1
#  Current loss 0.3055720925331116
#
# Epoch number 1
#  Current loss 0.26722317934036255
#
# Epoch number 1
#  Current loss 0.3011912703514099
#
# Epoch number 1
#  Current loss 0.2877989411354065
#
# Epoch number 1
#  Current loss 0.2723264694213867
#
# Epoch number 1
#  Current loss 0.15228021144866943
#
# Epoch number 1
#  Current loss 0.20233500003814697
#
# Epoch number 1
#  Current loss 0.25754958391189575
#
# Epoch number 1
#  Current loss 0.16286565363407135
#
# Epoch number 1
#  Current loss 0.2531217634677887
#
# Epoch number 1
#  Current loss 0.3739369511604309
#
# Epoch number 1
#  Current loss 0.43438300490379333
#
# Epoch number 1
#  Current loss 0.39792659878730774
#
# Epoch number 1
#  Current loss 0.32279062271118164
#
# Epoch number 1
#  Current loss 0.20718321204185486
#
# Epoch number 1
#  Current loss 0.17991703748703003
#
# Epoch number 1
#  Current loss 0.2224099487066269
#
# Epoch number 1
#  Current loss 0.21086449921131134
#
# Epoch number 1
#  Current loss 0.22614100575447083
#
# Epoch number 1
#  Current loss 0.2616874575614929
#
# Epoch number 1
#  Current loss 0.23702844977378845
#
# Epoch number 1
#  Current loss 0.2700021266937256
#
# Epoch number 1
#  Current loss 0.3263132572174072
#
# Epoch number 1
#  Current loss 0.3186734914779663
#
# Epoch number 1
#  Current loss 0.2471494972705841
#
# Epoch number 1
#  Current loss 0.25094956159591675
#
# Epoch number 1
#  Current loss 0.31736379861831665
#
# Epoch number 1
#  Current loss 0.3116121292114258
#
# Epoch number 1
#  Current loss 0.2845006585121155
#
# Epoch number 1
#  Current loss 0.2475494146347046
#
# Epoch number 1
#  Current loss 0.3223980665206909
#
# Epoch number 1
#  Current loss 0.20113900303840637
#
# Epoch number 1
#  Current loss 0.34115004539489746
#
# Epoch number 1
#  Current loss 0.23987559974193573
#
# Epoch number 1
#  Current loss 0.34216952323913574
#
# Epoch number 1
#  Current loss 0.21169444918632507
#
# Epoch number 1
#  Current loss 0.35639315843582153
#
# Epoch number 1
#  Current loss 0.23561646044254303
#
# Epoch number 1
#  Current loss 0.356393039226532
#
# Epoch number 1
#  Current loss 0.19705799221992493
#
# Epoch number 1
#  Current loss 0.26162344217300415
#
# Epoch number 1
#  Current loss 2.580886125564575
#
# Epoch number 1
#  Current loss 0.2223961353302002
#
# Epoch number 1
#  Current loss 0.2454107254743576
#
# Epoch number 1
#  Current loss 0.2257247269153595
#
# Epoch number 1
#  Current loss 0.19719263911247253
#
# Epoch number 1
#  Current loss 0.33114248514175415
#
# Epoch number 1
#  Current loss 0.18876567482948303
#
# Epoch number 1
#  Current loss 0.29126280546188354
#
# Epoch number 1
#  Current loss 0.17986610531806946
#
# Epoch number 1
#  Current loss 0.11514035612344742
#
# Epoch number 1
#  Current loss 0.27101069688796997
#
# Epoch number 1
#  Current loss 0.3918834328651428
#
# Epoch number 1
#  Current loss 0.28465908765792847
#
# Epoch number 1
#  Current loss 0.272518515586853
#
# Epoch number 1
#  Current loss 0.2949243187904358
#
# Epoch number 1
#  Current loss 0.2791823148727417
#
# Epoch number 1
#  Current loss 0.15446853637695312
#
# Epoch number 1
#  Current loss 0.2220936417579651
#
# Epoch number 1
#  Current loss 0.33395764231681824
#
# Epoch number 1
#  Current loss 0.2811657190322876
#
# Epoch number 1
#  Current loss 0.2903392016887665
#
# Epoch number 1
#  Current loss 0.5269679427146912
#
# Epoch number 1
#  Current loss 0.2989528477191925
#
# Epoch number 1
#  Current loss 0.19959188997745514
#
# Epoch number 1
#  Current loss 0.34398066997528076
#
# Epoch number 1
#  Current loss 0.13233482837677002
#
# Epoch number 1
#  Current loss 0.19317932426929474
#
# Epoch number 1
#  Current loss 0.258025199174881
#
# Epoch number 1
#  Current loss 0.48487573862075806
#
# Epoch number 1
#  Current loss 0.32829195261001587
#
# Epoch number 1
#  Current loss 0.28081753849983215
#
# Epoch number 1
#  Current loss 0.38335543870925903
#
# Epoch number 1
#  Current loss 0.27291154861450195
#
# Epoch number 1
#  Current loss 0.251537024974823
#
# Epoch number 1
#  Current loss 0.33633124828338623
#
# Epoch number 1
#  Current loss 0.39798182249069214
#
# Epoch number 1
#  Current loss 0.33483779430389404
#
# Epoch number 1
#  Current loss 0.2220216989517212
#
# Epoch number 1
#  Current loss 0.30097466707229614
#
# Epoch number 1
#  Current loss 0.2784891724586487
#
# Epoch number 1
#  Current loss 0.5635074377059937
#
# Epoch number 1
#  Current loss 0.2485552877187729
#
# Epoch number 1
#  Current loss 0.27888408303260803
#
# Epoch number 1
#  Current loss 0.33302703499794006
#
# Epoch number 1
#  Current loss 0.18401390314102173
#
# Epoch number 1
#  Current loss 0.315116822719574
#
# Epoch number 1
#  Current loss 0.2173055112361908
#
# Epoch number 1
#  Current loss 0.23389655351638794
#
# Epoch number 1
#  Current loss 0.33602839708328247
#
# Epoch number 1
#  Current loss 0.34278440475463867
#
# Epoch number 1
#  Current loss 0.28619879484176636
#
# Epoch number 1
#  Current loss 0.34768205881118774
#
# Epoch number 1
#  Current loss 0.25017452239990234
#
# Epoch number 1
#  Current loss 0.22447609901428223
#
# Epoch number 1
#  Current loss 0.3791011869907379
#
# Epoch number 1
#  Current loss 0.6516943573951721
#
# Epoch number 1
#  Current loss 0.20636063814163208
#
# Epoch number 1
#  Current loss 0.39101240038871765
#
# Epoch number 1
#  Current loss 0.42719894647598267
#
# Epoch number 1
#  Current loss 0.5016889572143555
#
# Epoch number 1
#  Current loss 0.15747907757759094
#
# Epoch number 1
#  Current loss 0.40659868717193604
#
# Epoch number 1
#  Current loss 0.3168953061103821
#
# Epoch number 1
#  Current loss 0.18012775480747223
#
# Epoch number 1
#  Current loss 0.2661370635032654
#
# Epoch number 1
#  Current loss 0.18690836429595947
#
# Epoch number 1
#  Current loss 0.31630799174308777
#
# Epoch number 1
#  Current loss 0.42814338207244873
#
# Epoch number 1
#  Current loss 0.306318998336792
#
# Epoch number 1
#  Current loss 0.32775434851646423
#
# Epoch number 1
#  Current loss 0.21337726712226868
#
# Epoch number 1
#  Current loss 0.32611751556396484
#
# Epoch number 1
#  Current loss 0.47538554668426514
#
# Epoch number 1
#  Current loss 0.20817862451076508
#
# Epoch number 1
#  Current loss 0.328566312789917
#
# Epoch number 1
#  Current loss 0.2620956301689148
#
# Epoch number 1
#  Current loss 0.2477668821811676
#
# Epoch number 1
#  Current loss 0.2847047746181488
#
# Epoch number 1
#  Current loss 0.6074923276901245
#
# Epoch number 1
#  Current loss 0.2413654327392578
#
# Epoch number 1
#  Current loss 0.24290500581264496
#
# Epoch number 1
#  Current loss 0.2996862530708313
#
# Epoch number 1
#  Current loss 0.19998827576637268
#
# Epoch number 1
#  Current loss 0.29409414529800415
#
# Epoch number 1
#  Current loss 0.27646851539611816
#
# Epoch number 1
#  Current loss 0.21999680995941162
#
# Epoch number 1
#  Current loss 0.28538984060287476
#
# Epoch number 1
#  Current loss 0.5461845397949219
#
# Epoch number 1
#  Current loss 0.2715182304382324
#
# Epoch number 1
#  Current loss 0.22449076175689697
#
# Epoch number 1
#  Current loss 0.22547945380210876
#
# Epoch number 1
#  Current loss 0.26990726590156555
#
# Epoch number 1
#  Current loss 0.2023106813430786
#
# Epoch number 1
#  Current loss 0.28726688027381897
#
# Epoch number 1
#  Current loss 0.2440352737903595
#
# Epoch number 1
#  Current loss 0.25902649760246277
#
# Epoch number 1
#  Current loss 0.28510499000549316
#
# Epoch number 1
#  Current loss 0.2732381820678711
#
# Epoch number 1
#  Current loss 0.3961144983768463
#
# Epoch number 1
#  Current loss 0.14833955466747284
#
# Epoch number 1
#  Current loss 0.398451030254364
#
# Epoch number 1
#  Current loss 0.15946224331855774
#
# Epoch number 1
#  Current loss 0.3607582449913025
#
# Epoch number 1
#  Current loss 0.3076205253601074
#
# Epoch number 1
#  Current loss 0.4439058303833008
#
# Epoch number 1
#  Current loss 0.3903878331184387
#
# Epoch number 1
#  Current loss 0.3359326124191284
#
# Epoch number 1
#  Current loss 0.3456713557243347
#
# Epoch number 1
#  Current loss 0.39691269397735596
#
# Epoch number 2
#  Current loss 0.26145094633102417
#
# Epoch number 2
#  Current loss 0.33926331996917725
#
# Epoch number 2
#  Current loss 0.321478009223938
#
# Epoch number 2
#  Current loss 0.2487979233264923
#
# Epoch number 2
#  Current loss 0.2585281729698181
#
# Epoch number 2
#  Current loss 0.24903224408626556
#
# Epoch number 2
#  Current loss 0.30055463314056396
#
# Epoch number 2
#  Current loss 0.266051322221756
#
# Epoch number 2
#  Current loss 0.28610727190971375
#
# Epoch number 2
#  Current loss 0.33442097902297974
#
# Epoch number 2
#  Current loss 0.24406883120536804
#
# Epoch number 2
#  Current loss 0.2677445411682129
#
# Epoch number 2
#  Current loss 0.3149789571762085
#
# Epoch number 2
#  Current loss 0.33659827709198
#
# Epoch number 2
#  Current loss 0.24562644958496094
#
# Epoch number 2
#  Current loss 0.19925068318843842
#
# Epoch number 2
#  Current loss 0.3422253131866455
#
# Epoch number 2
#  Current loss 0.3025876581668854
#
# Epoch number 2
#  Current loss 0.31756114959716797
#
# Epoch number 2
#  Current loss 0.30633217096328735
#
# Epoch number 2
#  Current loss 0.27368390560150146
#
# Epoch number 2
#  Current loss 0.22940212488174438
#
# Epoch number 2
#  Current loss 0.2288801372051239
#
# Epoch number 2
#  Current loss 0.22935909032821655
#
# Epoch number 2
#  Current loss 0.21131712198257446
#
# Epoch number 2
#  Current loss 0.2622836232185364
#
# Epoch number 2
#  Current loss 0.41323360800743103
#
# Epoch number 2
#  Current loss 0.2861904799938202
#
# Epoch number 2
#  Current loss 0.27957260608673096
#
# Epoch number 2
#  Current loss 0.2779974937438965
#
# Epoch number 2
#  Current loss 0.2285839021205902
#
# Epoch number 2
#  Current loss 0.2747243642807007
#
# Epoch number 2
#  Current loss 0.214838445186615
#
# Epoch number 2
#  Current loss 0.21166707575321198
#
# Epoch number 2
#  Current loss 0.2027510702610016
#
# Epoch number 2
#  Current loss 0.22761374711990356
#
# Epoch number 2
#  Current loss 0.3307502269744873
#
# Epoch number 2
#  Current loss 0.24162575602531433
#
# Epoch number 2
#  Current loss 0.2556828558444977
#
# Epoch number 2
#  Current loss 0.24701786041259766
#
# Epoch number 2
#  Current loss 0.35623252391815186
#
# Epoch number 2
#  Current loss 0.213640034198761
#
# Epoch number 2
#  Current loss 0.2410830557346344
#
# Epoch number 2
#  Current loss 0.4210358262062073
#
# Epoch number 2
#  Current loss 0.2965618371963501
#
# Epoch number 2
#  Current loss 0.31244292855262756
#
# Epoch number 2
#  Current loss 0.2026228904724121
#
# Epoch number 2
#  Current loss 0.289864182472229
#
# Epoch number 2
#  Current loss 0.2940015494823456
#
# Epoch number 2
#  Current loss 0.2931813597679138
#
# Epoch number 2
#  Current loss 0.5961412191390991
#
# Epoch number 2
#  Current loss 0.25495749711990356
#
# Epoch number 2
#  Current loss 0.22080212831497192
#
# Epoch number 2
#  Current loss 0.26363396644592285
#
# Epoch number 2
#  Current loss 0.2556608319282532
#
# Epoch number 2
#  Current loss 0.25213316082954407
#
# Epoch number 2
#  Current loss 0.24797505140304565
#
# Epoch number 2
#  Current loss 0.24791432917118073
#
# Epoch number 2
#  Current loss 0.26485487818717957
#
# Epoch number 2
#  Current loss 0.27429986000061035
#
# Epoch number 2
#  Current loss 0.34863895177841187
#
# Epoch number 2
#  Current loss 0.3295649290084839
#
# Epoch number 2
#  Current loss 0.2861782908439636
#
# Epoch number 2
#  Current loss 0.2789093255996704
#
# Epoch number 2
#  Current loss 0.21148790419101715
#
# Epoch number 2
#  Current loss 0.35355550050735474
#
# Epoch number 2
#  Current loss 0.34845829010009766
#
# Epoch number 2
#  Current loss 0.18406477570533752
#
# Epoch number 2
#  Current loss 0.45060762763023376
#
# Epoch number 2
#  Current loss 0.25438565015792847
#
# Epoch number 2
#  Current loss 0.39291030168533325
#
# Epoch number 2
#  Current loss 0.36651718616485596
#
# Epoch number 2
#  Current loss 0.3583216369152069
#
# Epoch number 2
#  Current loss 0.5704566836357117
#
# Epoch number 2
#  Current loss 0.3767434358596802
#
# Epoch number 2
#  Current loss 0.42258143424987793
#
# Epoch number 2
#  Current loss 0.3391263782978058
#
# Epoch number 2
#  Current loss 0.19459395110607147
#
# Epoch number 2
#  Current loss 0.3413710296154022
#
# Epoch number 2
#  Current loss 0.1661178171634674
#
# Epoch number 2
#  Current loss 0.3327207565307617
#
# Epoch number 2
#  Current loss 0.29557690024375916
#
# Epoch number 2
#  Current loss 0.18050885200500488
#
# Epoch number 2
#  Current loss 0.263080358505249
#
# Epoch number 2
#  Current loss 0.9010990858078003
#
# Epoch number 2
#  Current loss 0.29362040758132935
#
# Epoch number 2
#  Current loss 0.1856936514377594
#
# Epoch number 2
#  Current loss 0.16634413599967957
#
# Epoch number 2
#  Current loss 0.39304104447364807
#
# Epoch number 2
#  Current loss 0.4780285358428955
#
# Epoch number 2
#  Current loss 0.38652950525283813
#
# Epoch number 2
#  Current loss 0.2743920087814331
#
# Epoch number 2
#  Current loss 0.29409897327423096
#
# Epoch number 2
#  Current loss 0.378004252910614
#
# Epoch number 2
#  Current loss 0.36412349343299866
#
# Epoch number 2
#  Current loss 0.3466028571128845
#
# Epoch number 2
#  Current loss 0.4121403098106384
#
# Epoch number 2
#  Current loss 0.2003287672996521
#
# Epoch number 2
#  Current loss 0.37415966391563416
#
# Epoch number 2
#  Current loss 0.297346830368042
#
# Epoch number 2
#  Current loss 0.20566311478614807
#
# Epoch number 2
#  Current loss 0.5104349851608276
#
# Epoch number 2
#  Current loss 0.3328431248664856
#
# Epoch number 2
#  Current loss 0.27177882194519043
#
# Epoch number 2
#  Current loss 0.3040384352207184
#
# Epoch number 2
#  Current loss 0.335628479719162
#
# Epoch number 2
#  Current loss 0.32636159658432007
#
# Epoch number 2
#  Current loss 0.21903547644615173
#
# Epoch number 2
#  Current loss 0.3185776472091675
#
# Epoch number 2
#  Current loss 0.2566319704055786
#
# Epoch number 2
#  Current loss 0.24091756343841553
#
# Epoch number 2
#  Current loss 0.18308329582214355
#
# Epoch number 2
#  Current loss 0.27716243267059326
#
# Epoch number 2
#  Current loss 0.4136812388896942
#
# Epoch number 2
#  Current loss 0.22964349389076233
#
# Epoch number 2
#  Current loss 0.25269848108291626
#
# Epoch number 2
#  Current loss 0.2948017120361328
#
# Epoch number 2
#  Current loss 0.2851664125919342
#
# Epoch number 2
#  Current loss 0.2582419514656067
#
# Epoch number 2
#  Current loss 0.3181862533092499
#
# Epoch number 2
#  Current loss 0.22533859312534332
#
# Epoch number 2
#  Current loss 0.26561421155929565
#
# Epoch number 2
#  Current loss 0.5380678176879883
#
# Epoch number 2
#  Current loss 0.19769996404647827
#
# Epoch number 2
#  Current loss 0.19352689385414124
#
# Epoch number 2
#  Current loss 0.25967293977737427
#
# Epoch number 2
#  Current loss 0.28211045265197754
#
# Epoch number 2
#  Current loss 0.27427664399147034
#
# Epoch number 2
#  Current loss 0.2642776370048523
#
# Epoch number 2
#  Current loss 0.27783340215682983
#
# Epoch number 2
#  Current loss 0.3192759156227112
#
# Epoch number 2
#  Current loss 0.26231586933135986
#
# Epoch number 2
#  Current loss 0.3762274980545044
#
# Epoch number 2
#  Current loss 0.42542025446891785
#
# Epoch number 2
#  Current loss 0.20684528350830078
#
# Epoch number 2
#  Current loss 0.3288252055644989
#
# Epoch number 2
#  Current loss 0.2048296481370926
#
# Epoch number 2
#  Current loss 0.2565969228744507
#
# Epoch number 2
#  Current loss 0.44988226890563965
#
# Epoch number 2
#  Current loss 0.3512539267539978
#
# Epoch number 2
#  Current loss 0.22825172543525696
#
# Epoch number 2
#  Current loss 0.22399768233299255
#
# Epoch number 2
#  Current loss 0.3713344633579254
#
# Epoch number 2
#  Current loss 0.23509719967842102
#
# Epoch number 2
#  Current loss 0.24916459619998932
#
# Epoch number 2
#  Current loss 0.2506965696811676
#
# Epoch number 2
#  Current loss 0.25444430112838745
#
# Epoch number 2
#  Current loss 0.20399388670921326
#
# Epoch number 2
#  Current loss 0.2983558475971222
#
# Epoch number 2
#  Current loss 0.27104806900024414
#
# Epoch number 2
#  Current loss 0.25503644347190857
#
# Epoch number 2
#  Current loss 0.3381645679473877
#
# Epoch number 2
#  Current loss 0.2888716757297516
#
# Epoch number 2
#  Current loss 0.337394654750824
#
# Epoch number 2
#  Current loss 0.1657097339630127
#
# Epoch number 2
#  Current loss 0.20335543155670166
#
# Epoch number 2
#  Current loss 0.42166563868522644
#
# Epoch number 2
#  Current loss 0.9300296306610107
#
# Epoch number 2
#  Current loss 0.15238958597183228
#
# Epoch number 2
#  Current loss 0.2748434841632843
#
# Epoch number 2
#  Current loss 0.22998127341270447
#
# Epoch number 2
#  Current loss 0.261709600687027
#
# Epoch number 2
#  Current loss 0.17564037442207336
#
# Epoch number 2
#  Current loss 0.3630971908569336
#
# Epoch number 2
#  Current loss 0.24700000882148743
#
# Epoch number 2
#  Current loss 0.21191155910491943
#
# Epoch number 2
#  Current loss 0.2676871418952942
#
# Epoch number 2
#  Current loss 0.22502094507217407
#
# Epoch number 2
#  Current loss 0.397047221660614
#
# Epoch number 2
#  Current loss 0.2453622668981552
#
# Epoch number 2
#  Current loss 0.2521769404411316
#
# Epoch number 2
#  Current loss 0.23603981733322144
#
# Epoch number 2
#  Current loss 0.19616425037384033
#
# Epoch number 3
#  Current loss 0.2512325048446655
#
# Epoch number 3
#  Current loss 0.2713887393474579
#
# Epoch number 3
#  Current loss 0.4056464731693268
#
# Epoch number 3
#  Current loss 0.4031650125980377
#
# Epoch number 3
#  Current loss 0.3026881814002991
#
# Epoch number 3
#  Current loss 0.40012142062187195
#
# Epoch number 3
#  Current loss 0.24387700855731964
#
# Epoch number 3
#  Current loss 0.29371020197868347
#
# Epoch number 3
#  Current loss 0.2732057571411133
#
# Epoch number 3
#  Current loss 0.364988774061203
#
# Epoch number 3
#  Current loss 0.3895227909088135
#
# Epoch number 3
#  Current loss 0.3077908754348755
#
# Epoch number 3
#  Current loss 0.2398487776517868
#
# Epoch number 3
#  Current loss 0.27196168899536133
#
# Epoch number 3
#  Current loss 0.28649404644966125
#
# Epoch number 3
#  Current loss 0.22290755808353424
#
# Epoch number 3
#  Current loss 0.21117018163204193
#
# Epoch number 3
#  Current loss 0.24490755796432495
#
# Epoch number 3
#  Current loss 0.2546365261077881
#
# Epoch number 3
#  Current loss 0.31836286187171936
#
# Epoch number 3
#  Current loss 0.35082265734672546
#
# Epoch number 3
#  Current loss 0.2472294270992279
#
# Epoch number 3
#  Current loss 0.21340399980545044
#
# Epoch number 3
#  Current loss 0.39292940497398376
#
# Epoch number 3
#  Current loss 0.10194186866283417
#
# Epoch number 3
#  Current loss 0.23871174454689026
#
# Epoch number 3
#  Current loss 0.22744908928871155
#
# Epoch number 3
#  Current loss 0.27549314498901367
#
# Epoch number 3
#  Current loss 0.24064287543296814
#
# Epoch number 3
#  Current loss 0.2708427906036377
#
# Epoch number 3
#  Current loss 0.8783811926841736
#
# Epoch number 3
#  Current loss 0.20461496710777283
#
# Epoch number 3
#  Current loss 0.4408717453479767
#
# Epoch number 3
#  Current loss 0.250698059797287
#
# Epoch number 3
#  Current loss 0.25992029905319214
#
# Epoch number 3
#  Current loss 0.2741139233112335
#
# Epoch number 3
#  Current loss 0.21248863637447357
#
# Epoch number 3
#  Current loss 0.20465901494026184
#
# Epoch number 3
#  Current loss 0.25633591413497925
#
# Epoch number 3
#  Current loss 0.2790808081626892
#
# Epoch number 3
#  Current loss 0.33220091462135315
#
# Epoch number 3
#  Current loss 0.29759299755096436
#
# Epoch number 3
#  Current loss 0.3290979266166687
#
# Epoch number 3
#  Current loss 0.1497783213853836
#
# Epoch number 3
#  Current loss 0.3176308274269104
#
# Epoch number 3
#  Current loss 0.21888446807861328
#
# Epoch number 3
#  Current loss 0.3711746335029602
#
# Epoch number 3
#  Current loss 0.2607976198196411
#
# Epoch number 3
#  Current loss 0.21431463956832886
#
# Epoch number 3
#  Current loss 0.1980152726173401
#
# Epoch number 3
#  Current loss 0.31433606147766113
#
# Epoch number 3
#  Current loss 0.2946927547454834
#
# Epoch number 3
#  Current loss 0.18556419014930725
#
# Epoch number 3
#  Current loss 0.26589077711105347
#
# Epoch number 3
#  Current loss 0.28392499685287476
#
# Epoch number 3
#  Current loss 0.2823292016983032
#
# Epoch number 3
#  Current loss 0.22830337285995483
#
# Epoch number 3
#  Current loss 0.2514548897743225
#
# Epoch number 3
#  Current loss 0.2929404079914093
#
# Epoch number 3
#  Current loss 0.17477789521217346
#
# Epoch number 3
#  Current loss 0.2640075087547302
#
# Epoch number 3
#  Current loss 0.4182246923446655
#
# Epoch number 3
#  Current loss 1.2654911279678345
#
# Epoch number 3
#  Current loss 0.22415390610694885
#
# Epoch number 3
#  Current loss 0.2883090376853943
#
# Epoch number 3
#  Current loss 0.4687778949737549
#
# Epoch number 3
#  Current loss 0.31737959384918213
#
# Epoch number 3
#  Current loss 0.31663447618484497
#
# Epoch number 3
#  Current loss 0.23483726382255554
#
# Epoch number 3
#  Current loss 0.38165098428726196
#
# Epoch number 3
#  Current loss 0.3206486403942108
#
# Epoch number 3
#  Current loss 0.2690724730491638
#
# Epoch number 3
#  Current loss 0.2233360856771469
#
# Epoch number 3
#  Current loss 0.3406496047973633
#
# Epoch number 3
#  Current loss 0.28565651178359985
#
# Epoch number 3
#  Current loss 0.28544068336486816
#
# Epoch number 3
#  Current loss 0.4431750178337097
#
# Epoch number 3
#  Current loss 0.18184012174606323
#
# Epoch number 3
#  Current loss 0.3254848122596741
#
# Epoch number 3
#  Current loss 0.3046681582927704
#
# Epoch number 3
#  Current loss 0.2234218567609787
#
# Epoch number 3
#  Current loss 0.2678099572658539
#
# Epoch number 3
#  Current loss 0.35812050104141235
#
# Epoch number 3
#  Current loss 0.6868762969970703
#
# Epoch number 3
#  Current loss 0.24450761079788208
#
# Epoch number 3
#  Current loss 0.3676128089427948
#
# Epoch number 3
#  Current loss 0.2619328200817108
#
# Epoch number 3
#  Current loss 0.35219526290893555
#
# Epoch number 3
#  Current loss 0.40090304613113403
#
# Epoch number 3
#  Current loss 0.25609883666038513
#
# Epoch number 3
#  Current loss 0.23487627506256104
#
# Epoch number 3
#  Current loss 0.28850436210632324
#
# Epoch number 3
#  Current loss 0.2340678721666336
#
# Epoch number 3
#  Current loss 0.27909448742866516
#
# Epoch number 3
#  Current loss 0.1386878341436386
#
# Epoch number 3
#  Current loss 0.19639790058135986
#
# Epoch number 3
#  Current loss 0.317471981048584
#
# Epoch number 3
#  Current loss 0.3681642413139343
#
# Epoch number 3
#  Current loss 0.29873397946357727
#
# Epoch number 3
#  Current loss 0.19634421169757843
#
# Epoch number 3
#  Current loss 0.2755213975906372
#
# Epoch number 3
#  Current loss 0.27908751368522644
#
# Epoch number 3
#  Current loss 0.23415426909923553
#
# Epoch number 3
#  Current loss 0.33819591999053955
#
# Epoch number 3
#  Current loss 0.1531391143798828
#
# Epoch number 3
#  Current loss 0.2700832486152649
#
# Epoch number 3
#  Current loss 0.3060295581817627
#
# Epoch number 3
#  Current loss 0.2326444834470749
#
# Epoch number 3
#  Current loss 0.27610135078430176
#
# Epoch number 3
#  Current loss 0.2707226872444153
#
# Epoch number 3
#  Current loss 0.33810287714004517
#
# Epoch number 3
#  Current loss 0.2314458191394806
#
# Epoch number 3
#  Current loss 0.2281104326248169
#
# Epoch number 3
#  Current loss 0.324951708316803
#
# Epoch number 3
#  Current loss 0.3906014561653137
#
# Epoch number 3
#  Current loss 0.2434626966714859
#
# Epoch number 3
#  Current loss 0.2562624216079712
#
# Epoch number 3
#  Current loss 0.2797771096229553
#
# Epoch number 3
#  Current loss 0.5535991191864014
#
# Epoch number 3
#  Current loss 0.28327545523643494
#
# Epoch number 3
#  Current loss 0.31184643507003784
#
# Epoch number 3
#  Current loss 0.286109983921051
#
# Epoch number 3
#  Current loss 0.3001699447631836
#
# Epoch number 3
#  Current loss 0.3195430636405945
#
# Epoch number 3
#  Current loss 0.23586735129356384
#
# Epoch number 3
#  Current loss 0.33043259382247925
#
# Epoch number 3
#  Current loss 0.24415059387683868
#
# Epoch number 3
#  Current loss 0.2213970571756363
#
# Epoch number 3
#  Current loss 0.3458332121372223
#
# Epoch number 3
#  Current loss 0.3553425967693329
#
# Epoch number 3
#  Current loss 0.47827181220054626
#
# Epoch number 3
#  Current loss 0.45017528533935547
#
# Epoch number 3
#  Current loss 0.186949223279953
#
# Epoch number 3
#  Current loss 0.30070722103118896
#
# Epoch number 3
#  Current loss 0.23934701085090637
#
# Epoch number 3
#  Current loss 0.27882933616638184
#
# Epoch number 3
#  Current loss 0.2544025182723999
#
# Epoch number 3
#  Current loss 0.31787940859794617
#
# Epoch number 3
#  Current loss 0.2467951476573944
#
# Epoch number 3
#  Current loss 0.18397676944732666
#
# Epoch number 3
#  Current loss 0.17188885807991028
#
# Epoch number 3
#  Current loss 0.2224055528640747
#
# Epoch number 3
#  Current loss 0.3603721857070923
#
# Epoch number 3
#  Current loss 0.796309769153595
#
# Epoch number 3
#  Current loss 0.28286492824554443
#
# Epoch number 3
#  Current loss 0.3830339312553406
#
# Epoch number 3
#  Current loss 0.1577112078666687
#
# Epoch number 3
#  Current loss 0.16993048787117004
#
# Epoch number 3
#  Current loss 0.5606088638305664
#
# Epoch number 3
#  Current loss 0.27345404028892517
#
# Epoch number 3
#  Current loss 0.18703779578208923
#
# Epoch number 3
#  Current loss 0.2883526682853699
#
# Epoch number 3
#  Current loss 0.5204838514328003
#
# Epoch number 3
#  Current loss 0.4766964018344879
#
# Epoch number 3
#  Current loss 1.2528494596481323
#
# Epoch number 3
#  Current loss 0.1556169092655182
#
# Epoch number 3
#  Current loss 0.24948585033416748
#
# Epoch number 3
#  Current loss 0.2653581500053406
#
# Epoch number 3
#  Current loss 8.108030319213867
#
# Epoch number 3
#  Current loss 0.3010094463825226
#
# Epoch number 3
#  Current loss 0.24702778458595276
#
# Epoch number 3
#  Current loss 0.26725319027900696
#
# Epoch number 3
#  Current loss 0.4326991140842438
#
# Epoch number 3
#  Current loss 0.17675457894802094
#
# Epoch number 3
#  Current loss 0.3216763436794281
#
# Epoch number 3
#  Current loss 0.20653289556503296
#
# Epoch number 3
#  Current loss 0.3245265483856201
#
# Epoch number 3
#  Current loss 0.22860410809516907
#
# Epoch number 3
#  Current loss 0.4482894539833069
#
# Epoch number 3
#  Current loss 0.31036028265953064
#
# Epoch number 3
#  Current loss 0.20946769416332245
#
# Epoch number 3
#  Current loss 0.34991252422332764
#
# Epoch number 3
#  Current loss 0.6004847884178162

# %%
show_plot(counter, loss_history)

# %% [markdown]
# - Finding the best dissimilarity threshold?
# - Return the absolute difference at the end of the siamese network and use a `BCEWithLogitsLoss` with, say, `Adam` as the optimizer, instead of the contrastive loss function defined above.
# - It is belived that triplet loss/contrastive loss outperform binary cross entropy loss for siamese networks.

# %%
torch.save(svn.state_dict(), "svn.pth")

# %%
model = SignatureVerificationNetwork().to(device)
model.load_state_dict(torch.load("svn.pth"))
# Out:
# <All keys matched successfully>

# %%
# Util
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose((npimg * 255).astype(np.uint8), (1, 2, 0)))
    plt.show()

# %%
dataiter = iter(test_loader)
x0, _, _ = next(dataiter)

for i in range(10):
    _, x1, label2 = next(dataiter)
    concatenated = torch.cat((x0,x1),0)
    
    output1, output2 = model(x0.to(device), x1.to(device))  # Shape: (1, 128) for both outputs.
    print(F.pairwise_distance(output1, output2))
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated), f"Dissimilarity: {euclidean_distance.item()}")
# Out:
# tensor([0.6333], device='cuda:0', grad_fn=<NormBackward1>)
# tensor([0.3858], device='cuda:0', grad_fn=<NormBackward1>)
# tensor([0.3778], device='cuda:0', grad_fn=<NormBackward1>)
# tensor([0.2377], device='cuda:0', grad_fn=<NormBackward1>)
# tensor([0.3630], device='cuda:0', grad_fn=<NormBackward1>)
# tensor([0.4157], device='cuda:0', grad_fn=<NormBackward1>)
# tensor([0.3063], device='cuda:0', grad_fn=<NormBackward1>)
# tensor([0.4173], device='cuda:0', grad_fn=<NormBackward1>)
# tensor([0.2160], device='cuda:0', grad_fn=<NormBackward1>)
# tensor([0.5210], device='cuda:0', grad_fn=<NormBackward1>)

# %%
accuracy = 0
counter = 0
correct = 0

model.eval()

for i, data in enumerate(test_loader,0): 
  x0, x1, label = data
  output1, output2 = model(x0.to(device),x1.to(device))
  diff = torch.abs(output1.to(device)-output2.to(device))
  label = int(label[0].tolist()[0])
  result = torch.max(diff, 1)[1].data[0].tolist()
  if label == result:
    correct += 1
  counter += 1

accuracy = (correct/len(test_loader))
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.4931159420289855
